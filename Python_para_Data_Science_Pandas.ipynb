# %% [markdown]
# <a href="https://colab.research.google.com/github/Pexe33/Data_Sciente/blob/main/Python_para_Data_Science_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=green> PYTHON PARA DATA SCIENCE - PANDAS
# ---

# %% [markdown]
# # <font color=green> 1. INTRODUÇÃO AO PYTHON
# ---

# %% [markdown]
# # 1.1 Introdução

# %% [markdown]
# > Python é uma linguagem de programação de alto nível com suporte a múltiplos paradigmas de programação. É um projeto *open source* e desde seu surgimento, em 1991, vem se tornando uma das linguagens de programação interpretadas mais populares.
# >
# > Nos últimos anos Python desenvolveu uma comunidade ativa de processamento científico e análise de dados e vem se destacando como uma das linguagens mais relevantes quando o assundo é ciência de dados e machine learning, tanto no ambiente acadêmico como também no mercado.

# %% [markdown]
# # 1.2 Instalação e ambiente de desenvolvimento

# %% [markdown]
# ### Instalação Local
#
# ### https://www.python.org/downloads/
# ### ou
# ### https://www.anaconda.com/distribution/

# %% [markdown]
# ### Google Colaboratory
#
# ### https://colab.research.google.com

# %% [markdown]
# ### Verificando versão

# %% [markdown]
# # 1.3 Trabalhando com dados

# %%
import pandas as pd

# %%
dataset = pd.read_csv('db.csv', sep = ';')

# %%
dataset
# Out:
#                                        Nome  ...      Valor
# 0                             Jetta Variant  ...   88078.64
# 1                                    Passat  ...  106161.94
# 2                                  Crossfox  ...   72832.16
# 3                                       DS5  ...  124549.07
# 4                          Aston Martin DB4  ...   92612.10
# 5                             Palio Weekend  ...   97497.73
# 6                                        A5  ...   56445.20
# 7                            Série 3 Cabrio  ...  112310.44
# 8                              Dodge Jorney  ...  120716.27
# 9                                    Carens  ...   76566.49
# 10                                Ford Edge  ...   71647.59
# 11                                  Courier  ...   73919.53
# 12                                     S-18  ...  112732.99
# 13                                       J5  ...   53183.38
# 14                             F-Type Coupé  ...  127488.42
# 15                                      RAM  ...   59910.40
# 16                                  Série 1  ...   61118.59
# 17                                       A3  ...   88552.39
# 18                                     XC90  ...   62696.69
# 19                           RS 3 Sportback  ...  101726.30
# 20                             Pajero Sport  ...  106147.38
# 21                                Série 1 M  ...   94564.40
# 22                      Lamborghini Obvious  ...  133529.84
# 23                    Effa Hafei Picape Baú  ...  125684.65
# 24                   Lamborghini Murciélago  ...  121596.21
# 25                                      Up!  ...   71367.10
# 26                       Fiesta Rocam Sedan  ...   95347.75
# 27                          Sandero Stepway  ...  105432.84
# 28                                 Cayman S  ...   57045.27
# 29                                      V40  ...  120432.70
# 30                           Classe SLS AMG  ...   70707.20
# 31                                   Gol G4  ...   69105.18
# 32                                    Linea  ...   59358.69
# 33                                Ford F100  ...   65955.40
# 34                                       J2  ...   60017.03
# 35                         Aston Martin DBS  ...  118909.52
# 36                               Pajero TR4  ...   51606.59
# 37                               Polo Sedan  ...  123281.87
# 38                               California  ...   69770.18
# 39                                      S60  ...  102609.54
# 40                                   Tucson  ...   67997.19
# 41                                     HB20  ...  135235.29
# 42                                   Optima  ...   86641.34
# 43                                    Logan  ...  136818.39
# 44                        Range Rover Vogue  ...  117626.73
# 45                                   Sonata  ...   56208.70
# 46                    Ford New Fiesta Sedan  ...   84222.65
# 47                     Série 5 Gran Turismo  ...   90781.65
# 48                                     CR-V  ...   64701.10
# 49                            Ford EcoSport  ...  126350.49
# 50                                    Versa  ...  148152.89
# 51                                 Classe E  ...  132298.83
# 52                                 Carnival  ...  137627.63
# 53         Aston Martin V8 Vantage Roadster  ...   80422.71
# 54                                   Hoggar  ...   56373.99
# 55                                       A1  ...   70846.03
# 56                 Aston Martin DB7 Vantage  ...  128694.23
# 57                                      CLA  ...  133329.19
# 58                                   Accord  ...  131961.43
# 59                              EXTRA 103EX  ...  112033.27
# 60                                  Sorento  ...   81399.35
# 61                                    Tiggo  ...   97163.10
# 62                         New Fiesta Hatch  ...   66007.16
# 63                            Jeep Renegade  ...  128776.22
# 64                     Lamborghini Ankonian  ...  142623.02
# 65                              Space Cross  ...  136930.13
# 66                                  Touareg  ...   66526.61
# 67                                 Classe M  ...  114154.87
# 68                       Lancer Evolution X  ...  142392.75
# 69                           Kangoo Express  ...  146716.91
# 70                                      SW4  ...  122485.68
# 71                             Cadillac ELR  ...   97951.03
# 72                                    Doblò  ...   78283.49
# 73                      Lamborghini Egoista  ...   83434.04
# 74                                      Fit  ...   77836.23
# 75                                       C5  ...   60813.92
# 76                              Celer Hatch  ...   91353.86
# 77                                    HB20S  ...  116281.21
# 78                              Cielo Hatch  ...  145197.70
# 79                                   Livina  ...   50742.10
# 80                                   Ducato  ...   73033.53
# 81                                    March  ...   54332.87
# 82                       Cadillac XTS sedan  ...   52207.45
# 83                   Lamborghini Centenario  ...   63578.50
# 84                                    Hilux  ...   64507.72
# 85                              Grand Siena  ...  115075.59
# 86                                   Symbol  ...  133030.60
# 87               Aston Martin V12 GT Zagato  ...  141591.86
# 88                                   Fusion  ...  100380.28
# 89                                 A4 Sedan  ...   96369.04
# 90                            Xsara Picasso  ...  142603.84
# 91                                   207 SW  ...  117709.67
# 92                                     Star  ...  102241.54
# 93                              Doblò Cargo  ...   96065.38
# 94                             Cadillac CTS  ...   53894.61
# 95                                  Cayenne  ...  123911.78
# 96                                      Fox  ...  101996.35
# 97                              Tiida Hatch  ...   83431.66
# 98                            Dodge Charger  ...  122975.63
# 99                                     Face  ...   93227.73
# 100                                   Prius  ...   58762.65
# 101                                    Idea  ...  139549.67
# 102                                      A8  ...  122016.42
# 103                          Série 1 Cabrio  ...   72731.98
# 104                                    Edge  ...   88416.54
# 105                      Cadillac ATS sedan  ...   73873.42
# 106          Lamborghini Asterion LPI 910-4  ...   70709.34
# 107                                Frontier  ...  115306.50
# 108                            Série 3 Sedã  ...   55924.63
# 109                       Lamborghini LM002  ...   85052.26
# 110                            Cadillac XLR  ...   56646.34
# 111                                A4 Avant  ...  138946.88
# 112                                EcoSport  ...  108256.72
# 113                                      J3  ...   58979.30
# 114                                      Q3  ...  114727.68
# 115                 Aston Martin V8 Vantage  ...  139661.48
# 116                             Z4 Roadster  ...   80382.24
# 117                   Lamborghini Ferruccio  ...  149157.17
# 118                                Ford Ka+  ...   87830.41
# 119                           Silver Shadow  ...  143568.22
# 120                 Classe C 63 AMG Touring  ...  138171.85
# 121                             Discovery 4  ...  115784.95
# 122                                Veloster  ...  146508.99
# 123                                Classe C  ...  137670.23
# 124                                   Camry  ...  138597.27
# 125                               C5 Tourer  ...  147627.81
# 126                                   R8 GT  ...   62999.02
# 127                                   Bongo  ...   91242.44
# 128                                     ASX  ...  149489.92
# 129                            Cadillac SRX  ...   63529.95
# 130                               Classe CL  ...   58525.41
# 131                              500 Abarth  ...   90345.05
# 132                     Aston Martin Cygnet  ...  147770.87
# 133                            Cadillac STS  ...  106617.71
# 134                        Aston Martin DB9  ...  104929.88
# 135                                 NX 200t  ...  100712.45
# 136                     Aston Martin One-77  ...  141982.93
# 137                      Lamborghini Veneno  ...  104038.79
# 138                                  Sentra  ...   88501.54
# 139                                  Jumper  ...   79782.02
# 140                                     i30  ...   86224.10
# 141                                      X6  ...  103596.18
# 142                                  Voyage  ...  148996.47
# 143                    Phantom I Phantom II  ...   60948.01
# 144                          Passat Variant  ...   69535.44
# 145                                    Clio  ...  111130.33
# 146                                Classe G  ...   65847.69
# 147                            Silver Ghost  ...   78096.06
# 148                        Série 3 M3 Coupé  ...   69219.89
# 149                     Gallardo LP 560 – 4  ...  144118.91
# 150                            Freelander 2  ...   77397.05
# 151                          Grand Cherokee  ...   68974.25
# 152                       Aston Martin DBR9  ...  125231.30
# 153                                    Soul  ...   85501.12
# 154                            Cadillac BLS  ...  137116.21
# 155                                  RX 350  ...  138823.81
# 156                                  Cayman  ...  117961.95
# 157                           Chana Utility  ...  132662.32
# 158                                  308 CC  ...  146405.79
# 159                             L200 Triton  ...   81999.21
# 160                                   Jetta  ...  140934.60
# 161                               C4 Lounge  ...   82366.81
# 162                               C4 Pallas  ...   70424.11
# 163                                   Equus  ...   53620.31
# 164                               Classe GL  ...   73389.18
# 165                      Range Rover Evoque  ...  111618.12
# 166                                Cherokee  ...  112187.37
# 167                                   Punto  ...  120812.57
# 168                              Grand Tour  ...  116031.04
# 169                                 Fluence  ...  125398.11
# 170        Effa Hafei Picape Cabine Simples  ...   76101.47
# 171                                 Durango  ...   75263.24
# 172                                 Boxster  ...  147387.76
# 173                             TT Roadster  ...   85311.40
# 174                       Lamborghini Jalpa  ...   54388.11
# 175                              Classe SLK  ...  124156.65
# 176                                    Golf  ...  146203.34
# 177                              C3 Picasso  ...   56453.94
# 178                                     V50  ...   68873.79
# 179                                 Picanto  ...   91667.61
# 180                                 Cadenza  ...   93776.52
# 181                              Etios Sedã  ...   66433.82
# 182                                  Alsvin  ...  109059.27
# 183                            Cadillac ATS  ...  122069.97
# 184                         Série 3 M3 Sedã  ...  113090.32
# 185                                Classe S  ...   89401.10
# 186                                      T6  ...   56842.79
# 187                        Aston Martin DB7  ...  146676.71
# 188                               207 Sedan  ...   89511.96
# 189                     Aston Martin Virage  ...   97290.18
# 190                                   Azera  ...  120673.56
# 191                         Vantage Volante  ...  114434.94
# 192                                Siena EL  ...  139546.69
# 193                         Palio Adventure  ...   95078.16
# 194                                   HB20X  ...   68091.77
# 195                                      HR  ...   61496.97
# 196                   Cadillac STS V-Series  ...  139669.30
# 197                           Série 1 Coupé  ...   80661.39
# 198                                SpaceFox  ...   61783.65
# 199                                     C30  ...   52805.91
# 200                                J3 Turin  ...  127024.75
# 201                                Classe B  ...  135543.00
# 202                                  Parati  ...  121708.73
# 203                   Cadillac CTS V-Series  ...  107342.68
# 204                                   Sedan  ...   57888.10
# 205                       Classe CLS 63 AMG  ...  118161.48
# 206                                Aircross  ...  142499.06
# 207                Aston Martin V12 Vantage  ...  128396.11
# 208                                 Sandero  ...  112350.61
# 209                              New Fiesta  ...  124661.38
# 210                                     XKR  ...   54263.16
# 211                                      X5  ...   62041.32
# 212                            Cadillac DTS  ...  129296.11
# 213                            Pajero Dakar  ...   60998.33
# 214                                Classe A  ...   58008.50
# 215                     Ford Focus Fastback  ...   82304.19
# 216                                 Partner  ...  114531.74
# 217                                      R8  ...  128565.61
# 218                Aston Martin DBS Volante  ...  126488.26
# 219                                  Mohave  ...  119074.55
# 220                                   Fusca  ...  130238.04
# 221                            Chana Family  ...  115760.17
# 222                                    XC40  ...  121248.00
# 223  Phantom I Jonckheere Aerodynamic Coupe  ...   98156.35
# 224                                   Boxer  ...  112146.80
# 225                             Chana Cargo  ...  102729.63
# 226                            Dodge Dakota  ...  141083.35
# 227                                      X1  ...  102968.76
# 228                                     GLA  ...   76310.01
# 229                       Range Rover Sport  ...  120481.74
# 230                                     DS3  ...   54559.18
# 231                                Veracruz  ...   92957.64
# 232    Cadillac CTS coupe, sedan, and wagon  ...  127810.06
# 233                                  i30 CW  ...   73311.75
# 234                             Phantom III  ...   65138.03
# 235                                A3 Sedan  ...   90141.47
# 236                Aston Martin DB9 Volante  ...   71160.36
# 237                            Série 7 Sedã  ...   67539.79
# 238                    Lamborghini Reventón  ...   67664.86
# 239                            Grand Livina  ...   68652.16
# 240                                     V60  ...  114728.74
# 241          Effa Hafei Picape Cabine Dupla  ...  141645.08
# 242                              Benni Mini  ...  126247.84
# 243                                     Uno  ...  128852.21
# 244                             L200 Savana  ...  132384.76
# 245                                Santa Fe  ...  129415.33
# 246                                     RS5  ...   89536.82
# 247                                  Cerato  ...   87975.30
# 248                                    XC60  ...   77675.79
# 249                                 LS 460L  ...   58881.67
# 250              Lamborghini Sesto Elemento  ...   55081.99
# 251                     Lamborghini Huracán  ...  118826.44
# 252                                      A7  ...  137627.62
# 253                            Phantom 2013  ...   51759.58
# 254                   Cadillac Ciel concept  ...   51667.06
# 255                              Classe GLK  ...   68934.03
# 256                        Aston Martin DB5  ...  122110.90
# 257                                   Macan  ...   90381.47
#
# [258 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
dataset[['Quilometragem', 'Valor']].describe()
# Out:
#        Quilometragem          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
dataset.info
# Out:
# <bound method DataFrame.info of                                        Nome  ...      Valor
# 0                             Jetta Variant  ...   88078.64
# 1                                    Passat  ...  106161.94
# 2                                  Crossfox  ...   72832.16
# 3                                       DS5  ...  124549.07
# 4                          Aston Martin DB4  ...   92612.10
# 5                             Palio Weekend  ...   97497.73
# 6                                        A5  ...   56445.20
# 7                            Série 3 Cabrio  ...  112310.44
# 8                              Dodge Jorney  ...  120716.27
# 9                                    Carens  ...   76566.49
# 10                                Ford Edge  ...   71647.59
# 11                                  Courier  ...   73919.53
# 12                                     S-18  ...  112732.99
# 13                                       J5  ...   53183.38
# 14                             F-Type Coupé  ...  127488.42
# 15                                      RAM  ...   59910.40
# 16                                  Série 1  ...   61118.59
# 17                                       A3  ...   88552.39
# 18                                     XC90  ...   62696.69
# 19                           RS 3 Sportback  ...  101726.30
# 20                             Pajero Sport  ...  106147.38
# 21                                Série 1 M  ...   94564.40
# 22                      Lamborghini Obvious  ...  133529.84
# 23                    Effa Hafei Picape Baú  ...  125684.65
# 24                   Lamborghini Murciélago  ...  121596.21
# 25                                      Up!  ...   71367.10
# 26                       Fiesta Rocam Sedan  ...   95347.75
# 27                          Sandero Stepway  ...  105432.84
# 28                                 Cayman S  ...   57045.27
# 29                                      V40  ...  120432.70
# 30                           Classe SLS AMG  ...   70707.20
# 31                                   Gol G4  ...   69105.18
# 32                                    Linea  ...   59358.69
# 33                                Ford F100  ...   65955.40
# 34                                       J2  ...   60017.03
# 35                         Aston Martin DBS  ...  118909.52
# 36                               Pajero TR4  ...   51606.59
# 37                               Polo Sedan  ...  123281.87
# 38                               California  ...   69770.18
# 39                                      S60  ...  102609.54
# 40                                   Tucson  ...   67997.19
# 41                                     HB20  ...  135235.29
# 42                                   Optima  ...   86641.34
# 43                                    Logan  ...  136818.39
# 44                        Range Rover Vogue  ...  117626.73
# 45                                   Sonata  ...   56208.70
# 46                    Ford New Fiesta Sedan  ...   84222.65
# 47                     Série 5 Gran Turismo  ...   90781.65
# 48                                     CR-V  ...   64701.10
# 49                            Ford EcoSport  ...  126350.49
# 50                                    Versa  ...  148152.89
# 51                                 Classe E  ...  132298.83
# 52                                 Carnival  ...  137627.63
# 53         Aston Martin V8 Vantage Roadster  ...   80422.71
# 54                                   Hoggar  ...   56373.99
# 55                                       A1  ...   70846.03
# 56                 Aston Martin DB7 Vantage  ...  128694.23
# 57                                      CLA  ...  133329.19
# 58                                   Accord  ...  131961.43
# 59                              EXTRA 103EX  ...  112033.27
# 60                                  Sorento  ...   81399.35
# 61                                    Tiggo  ...   97163.10
# 62                         New Fiesta Hatch  ...   66007.16
# 63                            Jeep Renegade  ...  128776.22
# 64                     Lamborghini Ankonian  ...  142623.02
# 65                              Space Cross  ...  136930.13
# 66                                  Touareg  ...   66526.61
# 67                                 Classe M  ...  114154.87
# 68                       Lancer Evolution X  ...  142392.75
# 69                           Kangoo Express  ...  146716.91
# 70                                      SW4  ...  122485.68
# 71                             Cadillac ELR  ...   97951.03
# 72                                    Doblò  ...   78283.49
# 73                      Lamborghini Egoista  ...   83434.04
# 74                                      Fit  ...   77836.23
# 75                                       C5  ...   60813.92
# 76                              Celer Hatch  ...   91353.86
# 77                                    HB20S  ...  116281.21
# 78                              Cielo Hatch  ...  145197.70
# 79                                   Livina  ...   50742.10
# 80                                   Ducato  ...   73033.53
# 81                                    March  ...   54332.87
# 82                       Cadillac XTS sedan  ...   52207.45
# 83                   Lamborghini Centenario  ...   63578.50
# 84                                    Hilux  ...   64507.72
# 85                              Grand Siena  ...  115075.59
# 86                                   Symbol  ...  133030.60
# 87               Aston Martin V12 GT Zagato  ...  141591.86
# 88                                   Fusion  ...  100380.28
# 89                                 A4 Sedan  ...   96369.04
# 90                            Xsara Picasso  ...  142603.84
# 91                                   207 SW  ...  117709.67
# 92                                     Star  ...  102241.54
# 93                              Doblò Cargo  ...   96065.38
# 94                             Cadillac CTS  ...   53894.61
# 95                                  Cayenne  ...  123911.78
# 96                                      Fox  ...  101996.35
# 97                              Tiida Hatch  ...   83431.66
# 98                            Dodge Charger  ...  122975.63
# 99                                     Face  ...   93227.73
# 100                                   Prius  ...   58762.65
# 101                                    Idea  ...  139549.67
# 102                                      A8  ...  122016.42
# 103                          Série 1 Cabrio  ...   72731.98
# 104                                    Edge  ...   88416.54
# 105                      Cadillac ATS sedan  ...   73873.42
# 106          Lamborghini Asterion LPI 910-4  ...   70709.34
# 107                                Frontier  ...  115306.50
# 108                            Série 3 Sedã  ...   55924.63
# 109                       Lamborghini LM002  ...   85052.26
# 110                            Cadillac XLR  ...   56646.34
# 111                                A4 Avant  ...  138946.88
# 112                                EcoSport  ...  108256.72
# 113                                      J3  ...   58979.30
# 114                                      Q3  ...  114727.68
# 115                 Aston Martin V8 Vantage  ...  139661.48
# 116                             Z4 Roadster  ...   80382.24
# 117                   Lamborghini Ferruccio  ...  149157.17
# 118                                Ford Ka+  ...   87830.41
# 119                           Silver Shadow  ...  143568.22
# 120                 Classe C 63 AMG Touring  ...  138171.85
# 121                             Discovery 4  ...  115784.95
# 122                                Veloster  ...  146508.99
# 123                                Classe C  ...  137670.23
# 124                                   Camry  ...  138597.27
# 125                               C5 Tourer  ...  147627.81
# 126                                   R8 GT  ...   62999.02
# 127                                   Bongo  ...   91242.44
# 128                                     ASX  ...  149489.92
# 129                            Cadillac SRX  ...   63529.95
# 130                               Classe CL  ...   58525.41
# 131                              500 Abarth  ...   90345.05
# 132                     Aston Martin Cygnet  ...  147770.87
# 133                            Cadillac STS  ...  106617.71
# 134                        Aston Martin DB9  ...  104929.88
# 135                                 NX 200t  ...  100712.45
# 136                     Aston Martin One-77  ...  141982.93
# 137                      Lamborghini Veneno  ...  104038.79
# 138                                  Sentra  ...   88501.54
# 139                                  Jumper  ...   79782.02
# 140                                     i30  ...   86224.10
# 141                                      X6  ...  103596.18
# 142                                  Voyage  ...  148996.47
# 143                    Phantom I Phantom II  ...   60948.01
# 144                          Passat Variant  ...   69535.44
# 145                                    Clio  ...  111130.33
# 146                                Classe G  ...   65847.69
# 147                            Silver Ghost  ...   78096.06
# 148                        Série 3 M3 Coupé  ...   69219.89
# 149                     Gallardo LP 560 – 4  ...  144118.91
# 150                            Freelander 2  ...   77397.05
# 151                          Grand Cherokee  ...   68974.25
# 152                       Aston Martin DBR9  ...  125231.30
# 153                                    Soul  ...   85501.12
# 154                            Cadillac BLS  ...  137116.21
# 155                                  RX 350  ...  138823.81
# 156                                  Cayman  ...  117961.95
# 157                           Chana Utility  ...  132662.32
# 158                                  308 CC  ...  146405.79
# 159                             L200 Triton  ...   81999.21
# 160                                   Jetta  ...  140934.60
# 161                               C4 Lounge  ...   82366.81
# 162                               C4 Pallas  ...   70424.11
# 163                                   Equus  ...   53620.31
# 164                               Classe GL  ...   73389.18
# 165                      Range Rover Evoque  ...  111618.12
# 166                                Cherokee  ...  112187.37
# 167                                   Punto  ...  120812.57
# 168                              Grand Tour  ...  116031.04
# 169                                 Fluence  ...  125398.11
# 170        Effa Hafei Picape Cabine Simples  ...   76101.47
# 171                                 Durango  ...   75263.24
# 172                                 Boxster  ...  147387.76
# 173                             TT Roadster  ...   85311.40
# 174                       Lamborghini Jalpa  ...   54388.11
# 175                              Classe SLK  ...  124156.65
# 176                                    Golf  ...  146203.34
# 177                              C3 Picasso  ...   56453.94
# 178                                     V50  ...   68873.79
# 179                                 Picanto  ...   91667.61
# 180                                 Cadenza  ...   93776.52
# 181                              Etios Sedã  ...   66433.82
# 182                                  Alsvin  ...  109059.27
# 183                            Cadillac ATS  ...  122069.97
# 184                         Série 3 M3 Sedã  ...  113090.32
# 185                                Classe S  ...   89401.10
# 186                                      T6  ...   56842.79
# 187                        Aston Martin DB7  ...  146676.71
# 188                               207 Sedan  ...   89511.96
# 189                     Aston Martin Virage  ...   97290.18
# 190                                   Azera  ...  120673.56
# 191                         Vantage Volante  ...  114434.94
# 192                                Siena EL  ...  139546.69
# 193                         Palio Adventure  ...   95078.16
# 194                                   HB20X  ...   68091.77
# 195                                      HR  ...   61496.97
# 196                   Cadillac STS V-Series  ...  139669.30
# 197                           Série 1 Coupé  ...   80661.39
# 198                                SpaceFox  ...   61783.65
# 199                                     C30  ...   52805.91
# 200                                J3 Turin  ...  127024.75
# 201                                Classe B  ...  135543.00
# 202                                  Parati  ...  121708.73
# 203                   Cadillac CTS V-Series  ...  107342.68
# 204                                   Sedan  ...   57888.10
# 205                       Classe CLS 63 AMG  ...  118161.48
# 206                                Aircross  ...  142499.06
# 207                Aston Martin V12 Vantage  ...  128396.11
# 208                                 Sandero  ...  112350.61
# 209                              New Fiesta  ...  124661.38
# 210                                     XKR  ...   54263.16
# 211                                      X5  ...   62041.32
# 212                            Cadillac DTS  ...  129296.11
# 213                            Pajero Dakar  ...   60998.33
# 214                                Classe A  ...   58008.50
# 215                     Ford Focus Fastback  ...   82304.19
# 216                                 Partner  ...  114531.74
# 217                                      R8  ...  128565.61
# 218                Aston Martin DBS Volante  ...  126488.26
# 219                                  Mohave  ...  119074.55
# 220                                   Fusca  ...  130238.04
# 221                            Chana Family  ...  115760.17
# 222                                    XC40  ...  121248.00
# 223  Phantom I Jonckheere Aerodynamic Coupe  ...   98156.35
# 224                                   Boxer  ...  112146.80
# 225                             Chana Cargo  ...  102729.63
# 226                            Dodge Dakota  ...  141083.35
# 227                                      X1  ...  102968.76
# 228                                     GLA  ...   76310.01
# 229                       Range Rover Sport  ...  120481.74
# 230                                     DS3  ...   54559.18
# 231                                Veracruz  ...   92957.64
# 232    Cadillac CTS coupe, sedan, and wagon  ...  127810.06
# 233                                  i30 CW  ...   73311.75
# 234                             Phantom III  ...   65138.03
# 235                                A3 Sedan  ...   90141.47
# 236                Aston Martin DB9 Volante  ...   71160.36
# 237                            Série 7 Sedã  ...   67539.79
# 238                    Lamborghini Reventón  ...   67664.86
# 239                            Grand Livina  ...   68652.16
# 240                                     V60  ...  114728.74
# 241          Effa Hafei Picape Cabine Dupla  ...  141645.08
# 242                              Benni Mini  ...  126247.84
# 243                                     Uno  ...  128852.21
# 244                             L200 Savana  ...  132384.76
# 245                                Santa Fe  ...  129415.33
# 246                                     RS5  ...   89536.82
# 247                                  Cerato  ...   87975.30
# 248                                    XC60  ...   77675.79
# 249                                 LS 460L  ...   58881.67
# 250              Lamborghini Sesto Elemento  ...   55081.99
# 251                     Lamborghini Huracán  ...  118826.44
# 252                                      A7  ...  137627.62
# 253                            Phantom 2013  ...   51759.58
# 254                   Cadillac Ciel concept  ...   51667.06
# 255                              Classe GLK  ...   68934.03
# 256                        Aston Martin DB5  ...  122110.90
# 257                                   Macan  ...   90381.47
#
# [258 rows x 7 columns]>

# %% [markdown]
# # <font color=green> 2. TRABALHANDO COM TUPLAS
# ---

# %% [markdown]
# # 2.1 Criando tuplas
#
# Tuplas são sequências imutáveis que são utilizadas para armazenar coleções de itens, geralmente heterogêneos. Podem ser construídas de várias formas:
# ```
# - Utilizando um par de parênteses: ( )
# - Utilizando uma vírgula à direita: x,
# - Utilizando um par de parênteses com itens separados por vírgulas: ( x, y, z )
# - Utilizando: tuple() ou tuple(iterador)
# ```

# %%
()
# Out:
# ()

# %%
1,2,3
# Out:
# (1, 2, 3)

# %%
nome = 'passat'
valor= '153000'
(nome,valor)
# Out:
# ('passat', '153000')

# %%
nomes_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
type(nomes_carros)
# Out:
# tuple

# %% [markdown]
# # 2.2 Seleções em tuplas

# %%
nomes_carros = tuple(['Jetta Variant', 'Passat', 'Crossfox', 'DS5'])
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
nomes_carros[0]
# Out:
# 'Jetta Variant'

# %%
nomes_carros[1]
# Out:
# 'Passat'

# %%
nomes_carros[-1]
# Out:
# 'DS5'

# %%
nomes_carros[1:3]
# Out:
# ('Passat', 'Crossfox')

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5', ('Fusca', 'Gol', 'C4'))

# %%
nomes_carros[-1]
# Out:
# ('Fusca', 'Gol', 'C4')

# %%
nomes_carros[-1][1]
# Out:
# 'Gol'

# %% [markdown]
# # 2.3 Iterando em tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros

# %%
for i in nomes_carros:
  print(i)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DS5
# ('Fusca', 'Gol', 'C4')

# %% [markdown]
# ### Desempacotamento de tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DS5')

# %%
carro_1, carro_2, carro_3, carro_4 = nomes_carros

# %%
carro_1
# Out:
# 'Jetta Variant'

# %%
carro_2
# Out:
# 'Passat'

# %%
carro_3
# Out:
# 'Crossfox'

# %%
carro_4
# Out:
# 'DS5'

# %%
_,A, _,B = nomes_carros

# %%
A
# Out:
# 'Passat'

# %%
B
# Out:
# 'DS5'

# %%
_, C, *_ = nomes_carros

# %%
C
# Out:
# 'Passat'

# %% [markdown]
# ## *zip()*
#
# https://docs.python.org/3.6/library/functions.html#zip

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
for i in zip(carros, valores):
  print(i)
# Out:
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.94)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)

# %%
for carro, valor in zip(carros, valores):
  print(carro, valor)
# Out:
# Jetta Variant 88078.64
# Passat 106161.94
# Crossfox 72832.16
# DS5 124549.07

# %%
for carro, valor in zip(carros, valores):
  if(valor > 100000):
    print(carro)
# Out:
# Passat
# DS5

# %% [markdown]
# # <font color=green> 3. TRABALHANDO COM DICIONÁRIOS
# ---

# %% [markdown]
# # 3.1 Criando dicionários
#
# Listas são coleções sequenciais, isto é, os itens destas sequências estão ordenados e utilizam índices (números inteiros) para acessar os valores.
#
# Os dicionários são coleções um pouco diferentes. São estruturas de dados que representam um tipo de mapeamento. Mapeamentos são coleções de associações entre pares de valores onde o primeiro elemento do par é conhecido como chave (*key*) e o segundo como valor (*value*).
#
# ```
# dicionario = {key_1: value_1, key_2: value_2, ..., key_n: value_n}
# ```
#
# https://docs.python.org/3.6/library/stdtypes.html#typesmapping

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
valores = [88078.64, 106161.94, 72832.16]
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
carros.index('Passat')
# Out:
# 1

# %%
valores[carros.index('Passat')]
# Out:
# 106161.94

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox':728232.16}
dados
# Out:
# {'Crossfox': 728232.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %%
type(dados)
# Out:
# dict

# %% [markdown]
# ### Criando dicionários com *zip()*

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64), ('Passat', 106161.94), ('Crossfox', 72832.16)]

# %%
dados = dict(zip(carros, valores))
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %% [markdown]
# # 3.2 Operações com dicionários

# %% [markdown]
# ## *dict[ key ]*
#
# Retorna o valor correspondente à chave (*key*) no dicionário.

# %%
dados['Passat']
# Out:
# 106161.94

# %% [markdown]
# ## *key in dict*
#
# Retorna **True** se a chave (*key*) for encontrada no dicionário.

# %%
'Passat' in dados
# Out:
# True

# %%
'Fusca' in dados
# Out:
# False

# %%
'Fusca' not in dados
# Out:
# True

# %% [markdown]
# ## *len(dict)*
#
# Retorna o número de itens do dicionário.

# %%
len(dados)
# Out:
# 3

# %% [markdown]
# ## *dict[ key ] = value*
#
# Inclui um item ao dicionário.

# %%
dados['DS5'] = 124549.07

# %%
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %% [markdown]
# ## *del dict[ key ]*
#
# Remove o item de chave (*key*) do dicionário.

# %%
del dados['Passat']
dados
# Out:
# {'Crossfox': 72832.16, 'DS5': 124549.07, 'Jetta Variant': 88078.64}

# %% [markdown]
# # 3.3 Métodos de dicionários

# %% [markdown]
# ## *dict.update()*
#
# Atualiza o dicionário.

# %%
dados.update({'Passat': 106161.94})
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
dados.update({'Passat': 106161.95, 'Fusca': 150000})
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %% [markdown]
# ## *dict.copy()*
#
# Cria uma cópia do dicionário.

# %%
dadosCopy = dados.copy()

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %%
del dadosCopy['Fusca']
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %%
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %% [markdown]
# ## *dict.pop(key[, default ])*
#
# Se a chave for encontrada no dicionário, o item é removido e seu valor é retornado. Caso contrário, o valor especificado como *default* é retornado. Se o valor *default* não for fornecido e a chave não for encontrada no dicionário um erro será gerado.

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %%
dadosCopy.pop('Passat')
# Out:
# 106161.95

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16, 'DS5': 124549.07, 'Jetta Variant': 88078.64}

# %%
dadosCopy.pop('Passat', 'Chave não encontrada')
# Out:
# 'Chave não encontrada'

# %%
dadosCopy.pop('DS5', 'Chave não encontrada')
# Out:
# 124549.07

# %% [markdown]
# ## *dict.clear()*
#
# Remove todos os itens do dicionário.

# %%
dadosCopy.clear()

# %%
dadosCopy
# Out:
# {}

# %% [markdown]
# # 3.4 Iterando em dicionários

# %% [markdown]
# ## *dict.keys()*
#
# Retorna uma lista contendo as chaves (*keys*) do dicionário.

# %%
dados.keys()
# Out:
# dict_keys(['Jetta Variant', 'Crossfox', 'DS5', 'Passat', 'Fusca'])

# %%
for i in dados.keys():
  print(i)
# Out:
# Jetta Variant
# Crossfox
# DS5
# Passat
# Fusca

# %% [markdown]
# ## *dict.values()*
#
# Retorna uma lista com todos os valores (*values*) do dicionário.

# %%
dados.values()
# Out:
# dict_values([88078.64, 72832.16, 124549.07, 106161.95, 150000])

# %% [markdown]
# ## *dict.items()*
#
# Retorna uma lista contendo uma tupla para cada par chave-valor (*key-value*) do dicionário.

# %%
dados.items()
# Out:
# dict_items([('Jetta Variant', 88078.64), ('Crossfox', 72832.16), ('DS5', 124549.07), ('Passat', 106161.95), ('Fusca', 150000)])

# %%
for i in dados.items():
  print(i)
# Out:
# ('Jetta Variant', 88078.64)
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)
# ('Passat', 106161.95)
# ('Fusca', 150000)

# %%
for key, value in dados.items():
  print(key, value)
# Out:
# Jetta Variant 88078.64
# Crossfox 72832.16
# DS5 124549.07
# Passat 106161.95
# Fusca 150000

# %%
for key, value in dados.items():
  if(value > 100000):
    print(key)
# Out:
# DS5
# Passat
# Fusca

# %% [markdown]
# # <font color=green> 4. FUNÇÕES E PACOTES
# ---
#
# Funções são unidades de código reutilizáveis que realizam uma tarefa específica, podem receber alguma entrada e também podem retornar alguma resultado.

# %% [markdown]
# # 4.1 Built-in function
#
# A linguagem Python possui várias funções integradas que estão sempre acessíveis. Algumas já utilizamos em nosso treinamento: type(), print(), zip(), len(), set() etc.
#
# https://docs.python.org/3.6/library/functions.html

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %%
#Forma "Difícil" de fazer a soma dos valores.

valores = []
for valor in dados.values():
  valores.append(valor)
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
soma = 0
for valor in dados.values():
  soma += valor
soma
# Out:
# 267072.74

# %%
list(dados.values())
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
#Jeito simples de fazer a soma.

sum(dados.values())
# Out:
# 267072.74

# %%
sum(dados.values(), 1000000)
# Out:
# 1267072.7399999998

# %%
print?

# %% [markdown]
# # 4.2 Definindo funções sem e com parâmetros

# %% [markdown]
# ### Funções sem parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>():
#     <instruções>
# ```

# %%
def media():
  valor = (1 + 2 + 3) / 3
  print(valor)

# %%
media()
# Out:
# 2.0

# %% [markdown]
# ### Funções com parâmetros
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
# ```

# %%
def media(number1, number2, number3):
  valor = (number1 + number2 + number3) / 3
  print(valor)

# %%
media(5, 10, 33)
# Out:
# 16.0

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  print(valor)

# %%
media([1, 2, 3,3,4,77])
# Out:
# 15.0

# %% [markdown]
# # 4.3 Definindo funções que retornam valores

# %% [markdown]
# ### Funções que retornam um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return <resultado>
# ```

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  return valor

# %%
media([1,2,3,4,5,6,7,8])
# Out:
# 4.5

# %%
resultado = media([1,2,3,4,5,6,7,8])
# Out:
# 4.5

# %%
resultado

# %% [markdown]
# ### Funções que retornam mais de um valor
#
# #### Formato padrão
#
# ```
# def <nome>(<param_1>, <param_2>, ..., <param_n>):
#     <instruções>
#     return (<resultado_1>, <resultado_2>, ..., <resultado_n>)
# ```

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  return (valor, len(lista))

# %%
media([1,2,3,4,5,6,7,8])
# Out:
# (4.5, 8)

# %%
resultado, n = media([1,2,3,4,5,6,7,8])

# %%
resultado
# Out:
# 4.5

# %%
n
# Out:
# 8

# %% [markdown]
# # <font color=green> 5. PANDAS BÁSICO
# ---
#
# **versão: 0.25.2**
#
# Pandas é uma ferramenta de manipulação de dados de alto nível, construída com base no pacote Numpy. O pacote pandas possui estruturas de dados bastante interessantes para manipulação de dados e por isso é muito utilizado por cientistas de dados.
#
#
# ## Estruturas de Dados
#
# ### Series
#
# Series são arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado. Os rótulos das linhas são chamados de **index**. A forma básica de criação de uma Series é a seguinte:
#
#
# ```
#     s = pd.Series(dados, index = index)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy ou uma constante.
#
# ### DataFrames
#
# DataFrame é uma estrutura de dados tabular bidimensional com rótulos nas linha e colunas. Como a Series, os DataFrames são capazes de armazenar qualquer tipo de dados.
#
#
# ```
#     df = pd.DataFrame(dados, index = index, columns = columns)
# ```
#
# O argumento *dados* pode ser um dicionário, uma lista, um array Numpy, uma Series e outro DataFrame.
#
# **Documentação:** https://pandas.pydata.org/pandas-docs/version/0.25/

# %% [markdown]
# # 5.1 Estruturas de dados

# %%
import pandas as pd

# %% [markdown]
# ### Criando uma Series a partir de uma lista

# %%
carros = ['Jetta Variant','Passat','Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
pd.Series(carros)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# ### Criando um DataFrame a partir de uma lista de dicionários

# %%
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]

# %%
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
dataset[['Nome','Motor','Ano','Quilometragem','Zero_km','Valor']]
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de um dicionário

# %%
dados = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de uma arquivo externo

# %%
dataset = pd.read_csv('db.csv', sep =";", index_col = 0)

# %%
dataset
# Out:
#                                                         Motor  ...      Valor
# Nome                                                           ...
# Jetta Variant                                 Motor 4.0 Turbo  ...   88078.64
# Passat                                           Motor Diesel  ...  106161.94
# Crossfox                                      Motor Diesel V8  ...   72832.16
# DS5                                           Motor 2.4 Turbo  ...  124549.07
# Aston Martin DB4                              Motor 2.4 Turbo  ...   92612.10
# Palio Weekend                                   Motor 1.8 16v  ...   97497.73
# A5                                            Motor 4.0 Turbo  ...   56445.20
# Série 3 Cabrio                                   Motor 1.0 8v  ...  112310.44
# Dodge Jorney                                    Motor 3.0 32v  ...  120716.27
# Carens                                  Motor 5.0 V8 Bi-Turbo  ...   76566.49
# Ford Edge                                     Motor Diesel V6  ...   71647.59
# Courier                                       Motor Diesel V8  ...   73919.53
# S-18                                                 Motor V6  ...  112732.99
# J5                                                   Motor V6  ...   53183.38
# F-Type Coupé                            Motor 5.0 V8 Bi-Turbo  ...  127488.42
# RAM                                           Motor Diesel V8  ...   59910.40
# Série 1                                         Motor 3.0 32v  ...   61118.59
# A3                                               Motor 1.0 8v  ...   88552.39
# XC90                                             Motor 1.0 8v  ...   62696.69
# RS 3 Sportback                                  Motor 3.0 32v  ...  101726.30
# Pajero Sport                                     Motor 1.0 8v  ...  106147.38
# Série 1 M                                            Motor V8  ...   94564.40
# Lamborghini Obvious                           Motor Diesel V6  ...  133529.84
# Effa Hafei Picape Baú                            Motor Diesel  ...  125684.65
# Lamborghini Murciélago                  Motor 5.0 V8 Bi-Turbo  ...  121596.21
# Up!                                           Motor Diesel V6  ...   71367.10
# Fiesta Rocam Sedan                            Motor 4.0 Turbo  ...   95347.75
# Sandero Stepway                                 Motor 3.0 32v  ...  105432.84
# Cayman S                                        Motor 3.0 32v  ...   57045.27
# V40                                           Motor 4.0 Turbo  ...  120432.70
# Classe SLS AMG                                   Motor 1.0 8v  ...   70707.20
# Gol G4                                          Motor 2.0 16v  ...   69105.18
# Linea                                            Motor 1.0 8v  ...   59358.69
# Ford F100                                       Motor 2.0 16v  ...   65955.40
# J2                                                   Motor V8  ...   60017.03
# Aston Martin DBS                                     Motor V8  ...  118909.52
# Pajero TR4                                    Motor 2.4 Turbo  ...   51606.59
# Polo Sedan                                           Motor V6  ...  123281.87
# California                                       Motor 1.0 8v  ...   69770.18
# S60                                           Motor 2.4 Turbo  ...  102609.54
# Tucson                                          Motor 2.0 16v  ...   67997.19
# HB20                                                 Motor V6  ...  135235.29
# Optima                                          Motor 1.8 16v  ...   86641.34
# Logan                                         Motor 4.0 Turbo  ...  136818.39
# Range Rover Vogue                                Motor 1.0 8v  ...  117626.73
# Sonata                                  Motor 5.0 V8 Bi-Turbo  ...   56208.70
# Ford New Fiesta Sedan                           Motor 3.0 32v  ...   84222.65
# Série 5 Gran Turismo                          Motor 4.0 Turbo  ...   90781.65
# CR-V                                          Motor Diesel V8  ...   64701.10
# Ford EcoSport                                    Motor 1.0 8v  ...  126350.49
# Versa                                           Motor 3.0 32v  ...  148152.89
# Classe E                                         Motor 1.0 8v  ...  132298.83
# Carnival                                             Motor V8  ...  137627.63
# Aston Martin V8 Vantage Roadster              Motor 2.4 Turbo  ...   80422.71
# Hoggar                                  Motor 5.0 V8 Bi-Turbo  ...   56373.99
# A1                                      Motor 5.0 V8 Bi-Turbo  ...   70846.03
# Aston Martin DB7 Vantage                             Motor V6  ...  128694.23
# CLA                                              Motor 1.0 8v  ...  133329.19
# Accord                                               Motor V8  ...  131961.43
# EXTRA 103EX                                     Motor 2.0 16v  ...  112033.27
# Sorento                                          Motor Diesel  ...   81399.35
# Tiggo                                           Motor 3.0 32v  ...   97163.10
# New Fiesta Hatch                                 Motor Diesel  ...   66007.16
# Jeep Renegade                           Motor 5.0 V8 Bi-Turbo  ...  128776.22
# Lamborghini Ankonian                            Motor 2.0 16v  ...  142623.02
# Space Cross                             Motor 5.0 V8 Bi-Turbo  ...  136930.13
# Touareg                                              Motor V8  ...   66526.61
# Classe M                                         Motor 1.0 8v  ...  114154.87
# Lancer Evolution X                            Motor Diesel V6  ...  142392.75
# Kangoo Express                                   Motor Diesel  ...  146716.91
# SW4                                           Motor Diesel V6  ...  122485.68
# Cadillac ELR                                     Motor 1.0 8v  ...   97951.03
# Doblò                                           Motor 1.8 16v  ...   78283.49
# Lamborghini Egoista                             Motor 3.0 32v  ...   83434.04
# Fit                                              Motor Diesel  ...   77836.23
# C5                                              Motor 2.0 16v  ...   60813.92
# Celer Hatch                                          Motor V8  ...   91353.86
# HB20S                                                Motor V8  ...  116281.21
# Cielo Hatch                                      Motor Diesel  ...  145197.70
# Livina                                          Motor 2.0 16v  ...   50742.10
# Ducato                                  Motor 5.0 V8 Bi-Turbo  ...   73033.53
# March                                                Motor V6  ...   54332.87
# Cadillac XTS sedan                            Motor Diesel V6  ...   52207.45
# Lamborghini Centenario                               Motor V6  ...   63578.50
# Hilux                                   Motor 5.0 V8 Bi-Turbo  ...   64507.72
# Grand Siena                                   Motor Diesel V8  ...  115075.59
# Symbol                                           Motor Diesel  ...  133030.60
# Aston Martin V12 GT Zagato                    Motor 4.0 Turbo  ...  141591.86
# Fusion                                          Motor 1.8 16v  ...  100380.28
# A4 Sedan                                         Motor Diesel  ...   96369.04
# Xsara Picasso                                   Motor 2.0 16v  ...  142603.84
# 207 SW                                          Motor 3.0 32v  ...  117709.67
# Star                                                 Motor V6  ...  102241.54
# Doblò Cargo                                     Motor 3.0 32v  ...   96065.38
# Cadillac CTS                                    Motor 1.8 16v  ...   53894.61
# Cayenne                                          Motor 1.0 8v  ...  123911.78
# Fox                                           Motor 4.0 Turbo  ...  101996.35
# Tiida Hatch                                   Motor Diesel V6  ...   83431.66
# Dodge Charger                                 Motor 2.4 Turbo  ...  122975.63
# Face                                                 Motor V8  ...   93227.73
# Prius                                           Motor 3.0 32v  ...   58762.65
# Idea                                                 Motor V6  ...  139549.67
# A8                                              Motor 2.0 16v  ...  122016.42
# Série 1 Cabrio                                  Motor 3.0 32v  ...   72731.98
# Edge                                                 Motor V6  ...   88416.54
# Cadillac ATS sedan                              Motor 1.8 16v  ...   73873.42
# Lamborghini Asterion LPI 910-4          Motor 5.0 V8 Bi-Turbo  ...   70709.34
# Frontier                                             Motor V8  ...  115306.50
# Série 3 Sedã                                    Motor 3.0 32v  ...   55924.63
# Lamborghini LM002                               Motor 1.8 16v  ...   85052.26
# Cadillac XLR                                  Motor Diesel V8  ...   56646.34
# A4 Avant                                         Motor Diesel  ...  138946.88
# EcoSport                                      Motor 4.0 Turbo  ...  108256.72
# J3                                              Motor 1.8 16v  ...   58979.30
# Q3                                              Motor 3.0 32v  ...  114727.68
# Aston Martin V8 Vantage                              Motor V8  ...  139661.48
# Z4 Roadster                                     Motor 3.0 32v  ...   80382.24
# Lamborghini Ferruccio                           Motor 3.0 32v  ...  149157.17
# Ford Ka+                                        Motor 1.8 16v  ...   87830.41
# Silver Shadow                                    Motor Diesel  ...  143568.22
# Classe C 63 AMG Touring                       Motor Diesel V8  ...  138171.85
# Discovery 4                                   Motor 4.0 Turbo  ...  115784.95
# Veloster                                      Motor Diesel V8  ...  146508.99
# Classe C                                      Motor Diesel V6  ...  137670.23
# Camry                                            Motor Diesel  ...  138597.27
# C5 Tourer                                     Motor Diesel V6  ...  147627.81
# R8 GT                                         Motor 4.0 Turbo  ...   62999.02
# Bongo                                         Motor Diesel V8  ...   91242.44
# ASX                                           Motor Diesel V8  ...  149489.92
# Cadillac SRX                            Motor 5.0 V8 Bi-Turbo  ...   63529.95
# Classe CL                                            Motor V8  ...   58525.41
# 500 Abarth                                           Motor V6  ...   90345.05
# Aston Martin Cygnet                     Motor 5.0 V8 Bi-Turbo  ...  147770.87
# Cadillac STS                                  Motor 4.0 Turbo  ...  106617.71
# Aston Martin DB9                                Motor 1.8 16v  ...  104929.88
# NX 200t                                       Motor 2.4 Turbo  ...  100712.45
# Aston Martin One-77                                  Motor V6  ...  141982.93
# Lamborghini Veneno                              Motor 3.0 32v  ...  104038.79
# Sentra                                          Motor 2.0 16v  ...   88501.54
# Jumper                                        Motor 2.4 Turbo  ...   79782.02
# i30                                             Motor 1.8 16v  ...   86224.10
# X6                                            Motor Diesel V6  ...  103596.18
# Voyage                                  Motor 5.0 V8 Bi-Turbo  ...  148996.47
# Phantom I Phantom II                            Motor 1.8 16v  ...   60948.01
# Passat Variant                                   Motor 1.0 8v  ...   69535.44
# Clio                                             Motor Diesel  ...  111130.33
# Classe G                                      Motor Diesel V6  ...   65847.69
# Silver Ghost                                    Motor 1.8 16v  ...   78096.06
# Série 3 M3 Coupé                                 Motor Diesel  ...   69219.89
# Gallardo LP 560 – 4                              Motor Diesel  ...  144118.91
# Freelander 2                                  Motor Diesel V6  ...   77397.05
# Grand Cherokee                          Motor 5.0 V8 Bi-Turbo  ...   68974.25
# Aston Martin DBR9                             Motor 4.0 Turbo  ...  125231.30
# Soul                                    Motor 5.0 V8 Bi-Turbo  ...   85501.12
# Cadillac BLS                                         Motor V8  ...  137116.21
# RX 350                                               Motor V6  ...  138823.81
# Cayman                                          Motor 3.0 32v  ...  117961.95
# Chana Utility                                    Motor Diesel  ...  132662.32
# 308 CC                                        Motor 4.0 Turbo  ...  146405.79
# L200 Triton                                   Motor Diesel V8  ...   81999.21
# Jetta                                   Motor 5.0 V8 Bi-Turbo  ...  140934.60
# C4 Lounge                                            Motor V8  ...   82366.81
# C4 Pallas                                        Motor 1.0 8v  ...   70424.11
# Equus                                           Motor 3.0 32v  ...   53620.31
# Classe GL                                       Motor 3.0 32v  ...   73389.18
# Range Rover Evoque                              Motor 2.0 16v  ...  111618.12
# Cherokee                                      Motor 4.0 Turbo  ...  112187.37
# Punto                                         Motor 4.0 Turbo  ...  120812.57
# Grand Tour                                      Motor 3.0 32v  ...  116031.04
# Fluence                                       Motor Diesel V6  ...  125398.11
# Effa Hafei Picape Cabine Simples                 Motor 1.0 8v  ...   76101.47
# Durango                                         Motor 2.0 16v  ...   75263.24
# Boxster                                       Motor Diesel V8  ...  147387.76
# TT Roadster                                      Motor Diesel  ...   85311.40
# Lamborghini Jalpa                               Motor 1.8 16v  ...   54388.11
# Classe SLK                                    Motor 4.0 Turbo  ...  124156.65
# Golf                                             Motor 1.0 8v  ...  146203.34
# C3 Picasso                                      Motor 3.0 32v  ...   56453.94
# V50                                             Motor 2.0 16v  ...   68873.79
# Picanto                                       Motor 4.0 Turbo  ...   91667.61
# Cadenza                                       Motor Diesel V6  ...   93776.52
# Etios Sedã                              Motor 5.0 V8 Bi-Turbo  ...   66433.82
# Alsvin                                        Motor Diesel V8  ...  109059.27
# Cadillac ATS                                  Motor Diesel V6  ...  122069.97
# Série 3 M3 Sedã                               Motor Diesel V6  ...  113090.32
# Classe S                                        Motor 3.0 32v  ...   89401.10
# T6                                              Motor 3.0 32v  ...   56842.79
# Aston Martin DB7                              Motor Diesel V8  ...  146676.71
# 207 Sedan                                     Motor 4.0 Turbo  ...   89511.96
# Aston Martin Virage                              Motor Diesel  ...   97290.18
# Azera                                           Motor 1.8 16v  ...  120673.56
# Vantage Volante                               Motor Diesel V8  ...  114434.94
# Siena EL                                             Motor V8  ...  139546.69
# Palio Adventure                               Motor Diesel V8  ...   95078.16
# HB20X                                                Motor V8  ...   68091.77
# HR                                      Motor 5.0 V8 Bi-Turbo  ...   61496.97
# Cadillac STS V-Series                           Motor 2.0 16v  ...  139669.30
# Série 1 Coupé                                    Motor 1.0 8v  ...   80661.39
# SpaceFox                                             Motor V8  ...   61783.65
# C30                                              Motor 1.0 8v  ...   52805.91
# J3 Turin                                             Motor V6  ...  127024.75
# Classe B                                      Motor Diesel V8  ...  135543.00
# Parati                                        Motor Diesel V8  ...  121708.73
# Cadillac CTS V-Series                         Motor 4.0 Turbo  ...  107342.68
# Sedan                                                Motor V8  ...   57888.10
# Classe CLS 63 AMG                             Motor Diesel V6  ...  118161.48
# Aircross                                         Motor 1.0 8v  ...  142499.06
# Aston Martin V12 Vantage                             Motor V8  ...  128396.11
# Sandero                                          Motor Diesel  ...  112350.61
# New Fiesta                              Motor 5.0 V8 Bi-Turbo  ...  124661.38
# XKR                                              Motor Diesel  ...   54263.16
# X5                                               Motor Diesel  ...   62041.32
# Cadillac DTS                                    Motor 1.8 16v  ...  129296.11
# Pajero Dakar                                  Motor 4.0 Turbo  ...   60998.33
# Classe A                                         Motor 1.0 8v  ...   58008.50
# Ford Focus Fastback                           Motor 4.0 Turbo  ...   82304.19
# Partner                                       Motor 2.4 Turbo  ...  114531.74
# R8                                                   Motor V6  ...  128565.61
# Aston Martin DBS Volante                      Motor 4.0 Turbo  ...  126488.26
# Mohave                                        Motor Diesel V6  ...  119074.55
# Fusca                                           Motor 3.0 32v  ...  130238.04
# Chana Family                                         Motor V8  ...  115760.17
# XC40                                          Motor 2.4 Turbo  ...  121248.00
# Phantom I Jonckheere Aerodynamic Coupe          Motor 1.8 16v  ...   98156.35
# Boxer                                                Motor V6  ...  112146.80
# Chana Cargo                                     Motor 2.0 16v  ...  102729.63
# Dodge Dakota                                     Motor Diesel  ...  141083.35
# X1                                            Motor Diesel V8  ...  102968.76
# GLA                                              Motor 1.0 8v  ...   76310.01
# Range Rover Sport                                Motor 1.0 8v  ...  120481.74
# DS3                                             Motor 1.8 16v  ...   54559.18
# Veracruz                                      Motor Diesel V8  ...   92957.64
# Cadillac CTS coupe, sedan, and wagon                 Motor V8  ...  127810.06
# i30 CW                                           Motor Diesel  ...   73311.75
# Phantom III                                   Motor Diesel V6  ...   65138.03
# A3 Sedan                                             Motor V6  ...   90141.47
# Aston Martin DB9 Volante                        Motor 2.0 16v  ...   71160.36
# Série 7 Sedã                                     Motor Diesel  ...   67539.79
# Lamborghini Reventón                          Motor 4.0 Turbo  ...   67664.86
# Grand Livina                                    Motor 2.0 16v  ...   68652.16
# V60                                              Motor Diesel  ...  114728.74
# Effa Hafei Picape Cabine Dupla                       Motor V6  ...  141645.08
# Benni Mini                                           Motor V8  ...  126247.84
# Uno                                           Motor Diesel V6  ...  128852.21
# L200 Savana                                     Motor 2.0 16v  ...  132384.76
# Santa Fe                                        Motor 3.0 32v  ...  129415.33
# RS5                                                  Motor V6  ...   89536.82
# Cerato                                               Motor V6  ...   87975.30
# XC60                                          Motor 4.0 Turbo  ...   77675.79
# LS 460L                                       Motor Diesel V8  ...   58881.67
# Lamborghini Sesto Elemento                           Motor V8  ...   55081.99
# Lamborghini Huracán                                  Motor V8  ...  118826.44
# A7                                               Motor 1.0 8v  ...  137627.62
# Phantom 2013                                         Motor V8  ...   51759.58
# Cadillac Ciel concept                                Motor V8  ...   51667.06
# Classe GLK                              Motor 5.0 V8 Bi-Turbo  ...   68934.03
# Aston Martin DB5                                 Motor Diesel  ...  122110.90
# Macan                                         Motor Diesel V6  ...   90381.47
#
# [258 rows x 6 columns]

# %% [markdown]
# # 5.2 Seleções com DataFrames

# %% [markdown]
# ### Selecionando colunas

# %%
#Seleciona os 5 primeiros registros do DataFrame
dataset.head()
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Jetta Variant     Motor 4.0 Turbo  ...   88078.64
# Passat               Motor Diesel  ...  106161.94
# Crossfox          Motor Diesel V8  ...   72832.16
# DS5               Motor 2.4 Turbo  ...  124549.07
# Aston Martin DB4  Motor 2.4 Turbo  ...   92612.10
#
# [5 rows x 6 columns]

# %%
#Seleciona os dados da coluna 'Valor' obs: a coluna Indice sempre vem junto.

dataset['Valor']
# Out:
# Nome
# Jetta Variant                              88078.64
# Passat                                    106161.94
# Crossfox                                   72832.16
# DS5                                       124549.07
# Aston Martin DB4                           92612.10
# Palio Weekend                              97497.73
# A5                                         56445.20
# Série 3 Cabrio                            112310.44
# Dodge Jorney                              120716.27
# Carens                                     76566.49
# Ford Edge                                  71647.59
# Courier                                    73919.53
# S-18                                      112732.99
# J5                                         53183.38
# F-Type Coupé                              127488.42
# RAM                                        59910.40
# Série 1                                    61118.59
# A3                                         88552.39
# XC90                                       62696.69
# RS 3 Sportback                            101726.30
# Pajero Sport                              106147.38
# Série 1 M                                  94564.40
# Lamborghini Obvious                       133529.84
# Effa Hafei Picape Baú                     125684.65
# Lamborghini Murciélago                    121596.21
# Up!                                        71367.10
# Fiesta Rocam Sedan                         95347.75
# Sandero Stepway                           105432.84
# Cayman S                                   57045.27
# V40                                       120432.70
# Classe SLS AMG                             70707.20
# Gol G4                                     69105.18
# Linea                                      59358.69
# Ford F100                                  65955.40
# J2                                         60017.03
# Aston Martin DBS                          118909.52
# Pajero TR4                                 51606.59
# Polo Sedan                                123281.87
# California                                 69770.18
# S60                                       102609.54
# Tucson                                     67997.19
# HB20                                      135235.29
# Optima                                     86641.34
# Logan                                     136818.39
# Range Rover Vogue                         117626.73
# Sonata                                     56208.70
# Ford New Fiesta Sedan                      84222.65
# Série 5 Gran Turismo                       90781.65
# CR-V                                       64701.10
# Ford EcoSport                             126350.49
# Versa                                     148152.89
# Classe E                                  132298.83
# Carnival                                  137627.63
# Aston Martin V8 Vantage Roadster           80422.71
# Hoggar                                     56373.99
# A1                                         70846.03
# Aston Martin DB7 Vantage                  128694.23
# CLA                                       133329.19
# Accord                                    131961.43
# EXTRA 103EX                               112033.27
# Sorento                                    81399.35
# Tiggo                                      97163.10
# New Fiesta Hatch                           66007.16
# Jeep Renegade                             128776.22
# Lamborghini Ankonian                      142623.02
# Space Cross                               136930.13
# Touareg                                    66526.61
# Classe M                                  114154.87
# Lancer Evolution X                        142392.75
# Kangoo Express                            146716.91
# SW4                                       122485.68
# Cadillac ELR                               97951.03
# Doblò                                      78283.49
# Lamborghini Egoista                        83434.04
# Fit                                        77836.23
# C5                                         60813.92
# Celer Hatch                                91353.86
# HB20S                                     116281.21
# Cielo Hatch                               145197.70
# Livina                                     50742.10
# Ducato                                     73033.53
# March                                      54332.87
# Cadillac XTS sedan                         52207.45
# Lamborghini Centenario                     63578.50
# Hilux                                      64507.72
# Grand Siena                               115075.59
# Symbol                                    133030.60
# Aston Martin V12 GT Zagato                141591.86
# Fusion                                    100380.28
# A4 Sedan                                   96369.04
# Xsara Picasso                             142603.84
# 207 SW                                    117709.67
# Star                                      102241.54
# Doblò Cargo                                96065.38
# Cadillac CTS                               53894.61
# Cayenne                                   123911.78
# Fox                                       101996.35
# Tiida Hatch                                83431.66
# Dodge Charger                             122975.63
# Face                                       93227.73
# Prius                                      58762.65
# Idea                                      139549.67
# A8                                        122016.42
# Série 1 Cabrio                             72731.98
# Edge                                       88416.54
# Cadillac ATS sedan                         73873.42
# Lamborghini Asterion LPI 910-4             70709.34
# Frontier                                  115306.50
# Série 3 Sedã                               55924.63
# Lamborghini LM002                          85052.26
# Cadillac XLR                               56646.34
# A4 Avant                                  138946.88
# EcoSport                                  108256.72
# J3                                         58979.30
# Q3                                        114727.68
# Aston Martin V8 Vantage                   139661.48
# Z4 Roadster                                80382.24
# Lamborghini Ferruccio                     149157.17
# Ford Ka+                                   87830.41
# Silver Shadow                             143568.22
# Classe C 63 AMG Touring                   138171.85
# Discovery 4                               115784.95
# Veloster                                  146508.99
# Classe C                                  137670.23
# Camry                                     138597.27
# C5 Tourer                                 147627.81
# R8 GT                                      62999.02
# Bongo                                      91242.44
# ASX                                       149489.92
# Cadillac SRX                               63529.95
# Classe CL                                  58525.41
# 500 Abarth                                 90345.05
# Aston Martin Cygnet                       147770.87
# Cadillac STS                              106617.71
# Aston Martin DB9                          104929.88
# NX 200t                                   100712.45
# Aston Martin One-77                       141982.93
# Lamborghini Veneno                        104038.79
# Sentra                                     88501.54
# Jumper                                     79782.02
# i30                                        86224.10
# X6                                        103596.18
# Voyage                                    148996.47
# Phantom I Phantom II                       60948.01
# Passat Variant                             69535.44
# Clio                                      111130.33
# Classe G                                   65847.69
# Silver Ghost                               78096.06
# Série 3 M3 Coupé                           69219.89
# Gallardo LP 560 – 4                       144118.91
# Freelander 2                               77397.05
# Grand Cherokee                             68974.25
# Aston Martin DBR9                         125231.30
# Soul                                       85501.12
# Cadillac BLS                              137116.21
# RX 350                                    138823.81
# Cayman                                    117961.95
# Chana Utility                             132662.32
# 308 CC                                    146405.79
# L200 Triton                                81999.21
# Jetta                                     140934.60
# C4 Lounge                                  82366.81
# C4 Pallas                                  70424.11
# Equus                                      53620.31
# Classe GL                                  73389.18
# Range Rover Evoque                        111618.12
# Cherokee                                  112187.37
# Punto                                     120812.57
# Grand Tour                                116031.04
# Fluence                                   125398.11
# Effa Hafei Picape Cabine Simples           76101.47
# Durango                                    75263.24
# Boxster                                   147387.76
# TT Roadster                                85311.40
# Lamborghini Jalpa                          54388.11
# Classe SLK                                124156.65
# Golf                                      146203.34
# C3 Picasso                                 56453.94
# V50                                        68873.79
# Picanto                                    91667.61
# Cadenza                                    93776.52
# Etios Sedã                                 66433.82
# Alsvin                                    109059.27
# Cadillac ATS                              122069.97
# Série 3 M3 Sedã                           113090.32
# Classe S                                   89401.10
# T6                                         56842.79
# Aston Martin DB7                          146676.71
# 207 Sedan                                  89511.96
# Aston Martin Virage                        97290.18
# Azera                                     120673.56
# Vantage Volante                           114434.94
# Siena EL                                  139546.69
# Palio Adventure                            95078.16
# HB20X                                      68091.77
# HR                                         61496.97
# Cadillac STS V-Series                     139669.30
# Série 1 Coupé                              80661.39
# SpaceFox                                   61783.65
# C30                                        52805.91
# J3 Turin                                  127024.75
# Classe B                                  135543.00
# Parati                                    121708.73
# Cadillac CTS V-Series                     107342.68
# Sedan                                      57888.10
# Classe CLS 63 AMG                         118161.48
# Aircross                                  142499.06
# Aston Martin V12 Vantage                  128396.11
# Sandero                                   112350.61
# New Fiesta                                124661.38
# XKR                                        54263.16
# X5                                         62041.32
# Cadillac DTS                              129296.11
# Pajero Dakar                               60998.33
# Classe A                                   58008.50
# Ford Focus Fastback                        82304.19
# Partner                                   114531.74
# R8                                        128565.61
# Aston Martin DBS Volante                  126488.26
# Mohave                                    119074.55
# Fusca                                     130238.04
# Chana Family                              115760.17
# XC40                                      121248.00
# Phantom I Jonckheere Aerodynamic Coupe     98156.35
# Boxer                                     112146.80
# Chana Cargo                               102729.63
# Dodge Dakota                              141083.35
# X1                                        102968.76
# GLA                                        76310.01
# Range Rover Sport                         120481.74
# DS3                                        54559.18
# Veracruz                                   92957.64
# Cadillac CTS coupe, sedan, and wagon      127810.06
# i30 CW                                     73311.75
# Phantom III                                65138.03
# A3 Sedan                                   90141.47
# Aston Martin DB9 Volante                   71160.36
# Série 7 Sedã                               67539.79
# Lamborghini Reventón                       67664.86
# Grand Livina                               68652.16
# V60                                       114728.74
# Effa Hafei Picape Cabine Dupla            141645.08
# Benni Mini                                126247.84
# Uno                                       128852.21
# L200 Savana                               132384.76
# Santa Fe                                  129415.33
# RS5                                        89536.82
# Cerato                                     87975.30
# XC60                                       77675.79
# LS 460L                                    58881.67
# Lamborghini Sesto Elemento                 55081.99
# Lamborghini Huracán                       118826.44
# A7                                        137627.62
# Phantom 2013                               51759.58
# Cadillac Ciel concept                      51667.06
# Classe GLK                                 68934.03
# Aston Martin DB5                          122110.90
# Macan                                      90381.47
# Name: Valor, dtype: float64

# %%
type(dataset['Valor'])
# Out:
# pandas.core.series.Series

# %%
dataset[['Valor']]
# Out:
#                                             Valor
# Nome
# Jetta Variant                            88078.64
# Passat                                  106161.94
# Crossfox                                 72832.16
# DS5                                     124549.07
# Aston Martin DB4                         92612.10
# Palio Weekend                            97497.73
# A5                                       56445.20
# Série 3 Cabrio                          112310.44
# Dodge Jorney                            120716.27
# Carens                                   76566.49
# Ford Edge                                71647.59
# Courier                                  73919.53
# S-18                                    112732.99
# J5                                       53183.38
# F-Type Coupé                            127488.42
# RAM                                      59910.40
# Série 1                                  61118.59
# A3                                       88552.39
# XC90                                     62696.69
# RS 3 Sportback                          101726.30
# Pajero Sport                            106147.38
# Série 1 M                                94564.40
# Lamborghini Obvious                     133529.84
# Effa Hafei Picape Baú                   125684.65
# Lamborghini Murciélago                  121596.21
# Up!                                      71367.10
# Fiesta Rocam Sedan                       95347.75
# Sandero Stepway                         105432.84
# Cayman S                                 57045.27
# V40                                     120432.70
# Classe SLS AMG                           70707.20
# Gol G4                                   69105.18
# Linea                                    59358.69
# Ford F100                                65955.40
# J2                                       60017.03
# Aston Martin DBS                        118909.52
# Pajero TR4                               51606.59
# Polo Sedan                              123281.87
# California                               69770.18
# S60                                     102609.54
# Tucson                                   67997.19
# HB20                                    135235.29
# Optima                                   86641.34
# Logan                                   136818.39
# Range Rover Vogue                       117626.73
# Sonata                                   56208.70
# Ford New Fiesta Sedan                    84222.65
# Série 5 Gran Turismo                     90781.65
# CR-V                                     64701.10
# Ford EcoSport                           126350.49
# Versa                                   148152.89
# Classe E                                132298.83
# Carnival                                137627.63
# Aston Martin V8 Vantage Roadster         80422.71
# Hoggar                                   56373.99
# A1                                       70846.03
# Aston Martin DB7 Vantage                128694.23
# CLA                                     133329.19
# Accord                                  131961.43
# EXTRA 103EX                             112033.27
# Sorento                                  81399.35
# Tiggo                                    97163.10
# New Fiesta Hatch                         66007.16
# Jeep Renegade                           128776.22
# Lamborghini Ankonian                    142623.02
# Space Cross                             136930.13
# Touareg                                  66526.61
# Classe M                                114154.87
# Lancer Evolution X                      142392.75
# Kangoo Express                          146716.91
# SW4                                     122485.68
# Cadillac ELR                             97951.03
# Doblò                                    78283.49
# Lamborghini Egoista                      83434.04
# Fit                                      77836.23
# C5                                       60813.92
# Celer Hatch                              91353.86
# HB20S                                   116281.21
# Cielo Hatch                             145197.70
# Livina                                   50742.10
# Ducato                                   73033.53
# March                                    54332.87
# Cadillac XTS sedan                       52207.45
# Lamborghini Centenario                   63578.50
# Hilux                                    64507.72
# Grand Siena                             115075.59
# Symbol                                  133030.60
# Aston Martin V12 GT Zagato              141591.86
# Fusion                                  100380.28
# A4 Sedan                                 96369.04
# Xsara Picasso                           142603.84
# 207 SW                                  117709.67
# Star                                    102241.54
# Doblò Cargo                              96065.38
# Cadillac CTS                             53894.61
# Cayenne                                 123911.78
# Fox                                     101996.35
# Tiida Hatch                              83431.66
# Dodge Charger                           122975.63
# Face                                     93227.73
# Prius                                    58762.65
# Idea                                    139549.67
# A8                                      122016.42
# Série 1 Cabrio                           72731.98
# Edge                                     88416.54
# Cadillac ATS sedan                       73873.42
# Lamborghini Asterion LPI 910-4           70709.34
# Frontier                                115306.50
# Série 3 Sedã                             55924.63
# Lamborghini LM002                        85052.26
# Cadillac XLR                             56646.34
# A4 Avant                                138946.88
# EcoSport                                108256.72
# J3                                       58979.30
# Q3                                      114727.68
# Aston Martin V8 Vantage                 139661.48
# Z4 Roadster                              80382.24
# Lamborghini Ferruccio                   149157.17
# Ford Ka+                                 87830.41
# Silver Shadow                           143568.22
# Classe C 63 AMG Touring                 138171.85
# Discovery 4                             115784.95
# Veloster                                146508.99
# Classe C                                137670.23
# Camry                                   138597.27
# C5 Tourer                               147627.81
# R8 GT                                    62999.02
# Bongo                                    91242.44
# ASX                                     149489.92
# Cadillac SRX                             63529.95
# Classe CL                                58525.41
# 500 Abarth                               90345.05
# Aston Martin Cygnet                     147770.87
# Cadillac STS                            106617.71
# Aston Martin DB9                        104929.88
# NX 200t                                 100712.45
# Aston Martin One-77                     141982.93
# Lamborghini Veneno                      104038.79
# Sentra                                   88501.54
# Jumper                                   79782.02
# i30                                      86224.10
# X6                                      103596.18
# Voyage                                  148996.47
# Phantom I Phantom II                     60948.01
# Passat Variant                           69535.44
# Clio                                    111130.33
# Classe G                                 65847.69
# Silver Ghost                             78096.06
# Série 3 M3 Coupé                         69219.89
# Gallardo LP 560 – 4                     144118.91
# Freelander 2                             77397.05
# Grand Cherokee                           68974.25
# Aston Martin DBR9                       125231.30
# Soul                                     85501.12
# Cadillac BLS                            137116.21
# RX 350                                  138823.81
# Cayman                                  117961.95
# Chana Utility                           132662.32
# 308 CC                                  146405.79
# L200 Triton                              81999.21
# Jetta                                   140934.60
# C4 Lounge                                82366.81
# C4 Pallas                                70424.11
# Equus                                    53620.31
# Classe GL                                73389.18
# Range Rover Evoque                      111618.12
# Cherokee                                112187.37
# Punto                                   120812.57
# Grand Tour                              116031.04
# Fluence                                 125398.11
# Effa Hafei Picape Cabine Simples         76101.47
# Durango                                  75263.24
# Boxster                                 147387.76
# TT Roadster                              85311.40
# Lamborghini Jalpa                        54388.11
# Classe SLK                              124156.65
# Golf                                    146203.34
# C3 Picasso                               56453.94
# V50                                      68873.79
# Picanto                                  91667.61
# Cadenza                                  93776.52
# Etios Sedã                               66433.82
# Alsvin                                  109059.27
# Cadillac ATS                            122069.97
# Série 3 M3 Sedã                         113090.32
# Classe S                                 89401.10
# T6                                       56842.79
# Aston Martin DB7                        146676.71
# 207 Sedan                                89511.96
# Aston Martin Virage                      97290.18
# Azera                                   120673.56
# Vantage Volante                         114434.94
# Siena EL                                139546.69
# Palio Adventure                          95078.16
# HB20X                                    68091.77
# HR                                       61496.97
# Cadillac STS V-Series                   139669.30
# Série 1 Coupé                            80661.39
# SpaceFox                                 61783.65
# C30                                      52805.91
# J3 Turin                                127024.75
# Classe B                                135543.00
# Parati                                  121708.73
# Cadillac CTS V-Series                   107342.68
# Sedan                                    57888.10
# Classe CLS 63 AMG                       118161.48
# Aircross                                142499.06
# Aston Martin V12 Vantage                128396.11
# Sandero                                 112350.61
# New Fiesta                              124661.38
# XKR                                      54263.16
# X5                                       62041.32
# Cadillac DTS                            129296.11
# Pajero Dakar                             60998.33
# Classe A                                 58008.50
# Ford Focus Fastback                      82304.19
# Partner                                 114531.74
# R8                                      128565.61
# Aston Martin DBS Volante                126488.26
# Mohave                                  119074.55
# Fusca                                   130238.04
# Chana Family                            115760.17
# XC40                                    121248.00
# Phantom I Jonckheere Aerodynamic Coupe   98156.35
# Boxer                                   112146.80
# Chana Cargo                             102729.63
# Dodge Dakota                            141083.35
# X1                                      102968.76
# GLA                                      76310.01
# Range Rover Sport                       120481.74
# DS3                                      54559.18
# Veracruz                                 92957.64
# Cadillac CTS coupe, sedan, and wagon    127810.06
# i30 CW                                   73311.75
# Phantom III                              65138.03
# A3 Sedan                                 90141.47
# Aston Martin DB9 Volante                 71160.36
# Série 7 Sedã                             67539.79
# Lamborghini Reventón                     67664.86
# Grand Livina                             68652.16
# V60                                     114728.74
# Effa Hafei Picape Cabine Dupla          141645.08
# Benni Mini                              126247.84
# Uno                                     128852.21
# L200 Savana                             132384.76
# Santa Fe                                129415.33
# RS5                                      89536.82
# Cerato                                   87975.30
# XC60                                     77675.79
# LS 460L                                  58881.67
# Lamborghini Sesto Elemento               55081.99
# Lamborghini Huracán                     118826.44
# A7                                      137627.62
# Phantom 2013                             51759.58
# Cadillac Ciel concept                    51667.06
# Classe GLK                               68934.03
# Aston Martin DB5                        122110.90
# Macan                                    90381.47

# %% [markdown]
# ### Selecionando linhas - [ i : j ]
#
# <font color=red>**Observação:**</font> A indexação tem origem no zero e nos fatiamentos (*slices*) a linha com índice i é **incluída** e a linha com índice j **não é incluída** no resultado.

# %%
dataset[0:4]
# Out:
#                          Motor  ...      Valor
# Nome                            ...
# Jetta Variant  Motor 4.0 Turbo  ...   88078.64
# Passat            Motor Diesel  ...  106161.94
# Crossfox       Motor Diesel V8  ...   72832.16
# DS5            Motor 2.4 Turbo  ...  124549.07
#
# [4 rows x 6 columns]

# %% [markdown]
# ### Utilizando .loc para seleções
#
# <font color=red>**Observação:**</font> Seleciona um grupo de linhas e colunas segundo os rótulos ou uma matriz booleana.

# %%
#Series

dataset.loc['Passat']
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                                 5712
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                       106162
# Name: Passat, dtype: object

# %%
#DataFrame

dataset.loc[['Passat','DS5']]
# Out:
#                   Motor  ...      Valor
# Nome                     ...
# Passat     Motor Diesel  ...  106161.94
# DS5     Motor 2.4 Turbo  ...  124549.07
#
# [2 rows x 6 columns]

# %%
#Faz uma localização precisa
#[[Rotulos][Colunas]]

dataset.loc[['Passat','DS5'], ['Motor','Valor']]
# Out:
#                   Motor      Valor
# Nome
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
#Trás todas as linhas

dataset.loc[:, ['Motor','Valor']]
# Out:
#                                                         Motor      Valor
# Nome
# Jetta Variant                                 Motor 4.0 Turbo   88078.64
# Passat                                           Motor Diesel  106161.94
# Crossfox                                      Motor Diesel V8   72832.16
# DS5                                           Motor 2.4 Turbo  124549.07
# Aston Martin DB4                              Motor 2.4 Turbo   92612.10
# Palio Weekend                                   Motor 1.8 16v   97497.73
# A5                                            Motor 4.0 Turbo   56445.20
# Série 3 Cabrio                                   Motor 1.0 8v  112310.44
# Dodge Jorney                                    Motor 3.0 32v  120716.27
# Carens                                  Motor 5.0 V8 Bi-Turbo   76566.49
# Ford Edge                                     Motor Diesel V6   71647.59
# Courier                                       Motor Diesel V8   73919.53
# S-18                                                 Motor V6  112732.99
# J5                                                   Motor V6   53183.38
# F-Type Coupé                            Motor 5.0 V8 Bi-Turbo  127488.42
# RAM                                           Motor Diesel V8   59910.40
# Série 1                                         Motor 3.0 32v   61118.59
# A3                                               Motor 1.0 8v   88552.39
# XC90                                             Motor 1.0 8v   62696.69
# RS 3 Sportback                                  Motor 3.0 32v  101726.30
# Pajero Sport                                     Motor 1.0 8v  106147.38
# Série 1 M                                            Motor V8   94564.40
# Lamborghini Obvious                           Motor Diesel V6  133529.84
# Effa Hafei Picape Baú                            Motor Diesel  125684.65
# Lamborghini Murciélago                  Motor 5.0 V8 Bi-Turbo  121596.21
# Up!                                           Motor Diesel V6   71367.10
# Fiesta Rocam Sedan                            Motor 4.0 Turbo   95347.75
# Sandero Stepway                                 Motor 3.0 32v  105432.84
# Cayman S                                        Motor 3.0 32v   57045.27
# V40                                           Motor 4.0 Turbo  120432.70
# Classe SLS AMG                                   Motor 1.0 8v   70707.20
# Gol G4                                          Motor 2.0 16v   69105.18
# Linea                                            Motor 1.0 8v   59358.69
# Ford F100                                       Motor 2.0 16v   65955.40
# J2                                                   Motor V8   60017.03
# Aston Martin DBS                                     Motor V8  118909.52
# Pajero TR4                                    Motor 2.4 Turbo   51606.59
# Polo Sedan                                           Motor V6  123281.87
# California                                       Motor 1.0 8v   69770.18
# S60                                           Motor 2.4 Turbo  102609.54
# Tucson                                          Motor 2.0 16v   67997.19
# HB20                                                 Motor V6  135235.29
# Optima                                          Motor 1.8 16v   86641.34
# Logan                                         Motor 4.0 Turbo  136818.39
# Range Rover Vogue                                Motor 1.0 8v  117626.73
# Sonata                                  Motor 5.0 V8 Bi-Turbo   56208.70
# Ford New Fiesta Sedan                           Motor 3.0 32v   84222.65
# Série 5 Gran Turismo                          Motor 4.0 Turbo   90781.65
# CR-V                                          Motor Diesel V8   64701.10
# Ford EcoSport                                    Motor 1.0 8v  126350.49
# Versa                                           Motor 3.0 32v  148152.89
# Classe E                                         Motor 1.0 8v  132298.83
# Carnival                                             Motor V8  137627.63
# Aston Martin V8 Vantage Roadster              Motor 2.4 Turbo   80422.71
# Hoggar                                  Motor 5.0 V8 Bi-Turbo   56373.99
# A1                                      Motor 5.0 V8 Bi-Turbo   70846.03
# Aston Martin DB7 Vantage                             Motor V6  128694.23
# CLA                                              Motor 1.0 8v  133329.19
# Accord                                               Motor V8  131961.43
# EXTRA 103EX                                     Motor 2.0 16v  112033.27
# Sorento                                          Motor Diesel   81399.35
# Tiggo                                           Motor 3.0 32v   97163.10
# New Fiesta Hatch                                 Motor Diesel   66007.16
# Jeep Renegade                           Motor 5.0 V8 Bi-Turbo  128776.22
# Lamborghini Ankonian                            Motor 2.0 16v  142623.02
# Space Cross                             Motor 5.0 V8 Bi-Turbo  136930.13
# Touareg                                              Motor V8   66526.61
# Classe M                                         Motor 1.0 8v  114154.87
# Lancer Evolution X                            Motor Diesel V6  142392.75
# Kangoo Express                                   Motor Diesel  146716.91
# SW4                                           Motor Diesel V6  122485.68
# Cadillac ELR                                     Motor 1.0 8v   97951.03
# Doblò                                           Motor 1.8 16v   78283.49
# Lamborghini Egoista                             Motor 3.0 32v   83434.04
# Fit                                              Motor Diesel   77836.23
# C5                                              Motor 2.0 16v   60813.92
# Celer Hatch                                          Motor V8   91353.86
# HB20S                                                Motor V8  116281.21
# Cielo Hatch                                      Motor Diesel  145197.70
# Livina                                          Motor 2.0 16v   50742.10
# Ducato                                  Motor 5.0 V8 Bi-Turbo   73033.53
# March                                                Motor V6   54332.87
# Cadillac XTS sedan                            Motor Diesel V6   52207.45
# Lamborghini Centenario                               Motor V6   63578.50
# Hilux                                   Motor 5.0 V8 Bi-Turbo   64507.72
# Grand Siena                                   Motor Diesel V8  115075.59
# Symbol                                           Motor Diesel  133030.60
# Aston Martin V12 GT Zagato                    Motor 4.0 Turbo  141591.86
# Fusion                                          Motor 1.8 16v  100380.28
# A4 Sedan                                         Motor Diesel   96369.04
# Xsara Picasso                                   Motor 2.0 16v  142603.84
# 207 SW                                          Motor 3.0 32v  117709.67
# Star                                                 Motor V6  102241.54
# Doblò Cargo                                     Motor 3.0 32v   96065.38
# Cadillac CTS                                    Motor 1.8 16v   53894.61
# Cayenne                                          Motor 1.0 8v  123911.78
# Fox                                           Motor 4.0 Turbo  101996.35
# Tiida Hatch                                   Motor Diesel V6   83431.66
# Dodge Charger                                 Motor 2.4 Turbo  122975.63
# Face                                                 Motor V8   93227.73
# Prius                                           Motor 3.0 32v   58762.65
# Idea                                                 Motor V6  139549.67
# A8                                              Motor 2.0 16v  122016.42
# Série 1 Cabrio                                  Motor 3.0 32v   72731.98
# Edge                                                 Motor V6   88416.54
# Cadillac ATS sedan                              Motor 1.8 16v   73873.42
# Lamborghini Asterion LPI 910-4          Motor 5.0 V8 Bi-Turbo   70709.34
# Frontier                                             Motor V8  115306.50
# Série 3 Sedã                                    Motor 3.0 32v   55924.63
# Lamborghini LM002                               Motor 1.8 16v   85052.26
# Cadillac XLR                                  Motor Diesel V8   56646.34
# A4 Avant                                         Motor Diesel  138946.88
# EcoSport                                      Motor 4.0 Turbo  108256.72
# J3                                              Motor 1.8 16v   58979.30
# Q3                                              Motor 3.0 32v  114727.68
# Aston Martin V8 Vantage                              Motor V8  139661.48
# Z4 Roadster                                     Motor 3.0 32v   80382.24
# Lamborghini Ferruccio                           Motor 3.0 32v  149157.17
# Ford Ka+                                        Motor 1.8 16v   87830.41
# Silver Shadow                                    Motor Diesel  143568.22
# Classe C 63 AMG Touring                       Motor Diesel V8  138171.85
# Discovery 4                                   Motor 4.0 Turbo  115784.95
# Veloster                                      Motor Diesel V8  146508.99
# Classe C                                      Motor Diesel V6  137670.23
# Camry                                            Motor Diesel  138597.27
# C5 Tourer                                     Motor Diesel V6  147627.81
# R8 GT                                         Motor 4.0 Turbo   62999.02
# Bongo                                         Motor Diesel V8   91242.44
# ASX                                           Motor Diesel V8  149489.92
# Cadillac SRX                            Motor 5.0 V8 Bi-Turbo   63529.95
# Classe CL                                            Motor V8   58525.41
# 500 Abarth                                           Motor V6   90345.05
# Aston Martin Cygnet                     Motor 5.0 V8 Bi-Turbo  147770.87
# Cadillac STS                                  Motor 4.0 Turbo  106617.71
# Aston Martin DB9                                Motor 1.8 16v  104929.88
# NX 200t                                       Motor 2.4 Turbo  100712.45
# Aston Martin One-77                                  Motor V6  141982.93
# Lamborghini Veneno                              Motor 3.0 32v  104038.79
# Sentra                                          Motor 2.0 16v   88501.54
# Jumper                                        Motor 2.4 Turbo   79782.02
# i30                                             Motor 1.8 16v   86224.10
# X6                                            Motor Diesel V6  103596.18
# Voyage                                  Motor 5.0 V8 Bi-Turbo  148996.47
# Phantom I Phantom II                            Motor 1.8 16v   60948.01
# Passat Variant                                   Motor 1.0 8v   69535.44
# Clio                                             Motor Diesel  111130.33
# Classe G                                      Motor Diesel V6   65847.69
# Silver Ghost                                    Motor 1.8 16v   78096.06
# Série 3 M3 Coupé                                 Motor Diesel   69219.89
# Gallardo LP 560 – 4                              Motor Diesel  144118.91
# Freelander 2                                  Motor Diesel V6   77397.05
# Grand Cherokee                          Motor 5.0 V8 Bi-Turbo   68974.25
# Aston Martin DBR9                             Motor 4.0 Turbo  125231.30
# Soul                                    Motor 5.0 V8 Bi-Turbo   85501.12
# Cadillac BLS                                         Motor V8  137116.21
# RX 350                                               Motor V6  138823.81
# Cayman                                          Motor 3.0 32v  117961.95
# Chana Utility                                    Motor Diesel  132662.32
# 308 CC                                        Motor 4.0 Turbo  146405.79
# L200 Triton                                   Motor Diesel V8   81999.21
# Jetta                                   Motor 5.0 V8 Bi-Turbo  140934.60
# C4 Lounge                                            Motor V8   82366.81
# C4 Pallas                                        Motor 1.0 8v   70424.11
# Equus                                           Motor 3.0 32v   53620.31
# Classe GL                                       Motor 3.0 32v   73389.18
# Range Rover Evoque                              Motor 2.0 16v  111618.12
# Cherokee                                      Motor 4.0 Turbo  112187.37
# Punto                                         Motor 4.0 Turbo  120812.57
# Grand Tour                                      Motor 3.0 32v  116031.04
# Fluence                                       Motor Diesel V6  125398.11
# Effa Hafei Picape Cabine Simples                 Motor 1.0 8v   76101.47
# Durango                                         Motor 2.0 16v   75263.24
# Boxster                                       Motor Diesel V8  147387.76
# TT Roadster                                      Motor Diesel   85311.40
# Lamborghini Jalpa                               Motor 1.8 16v   54388.11
# Classe SLK                                    Motor 4.0 Turbo  124156.65
# Golf                                             Motor 1.0 8v  146203.34
# C3 Picasso                                      Motor 3.0 32v   56453.94
# V50                                             Motor 2.0 16v   68873.79
# Picanto                                       Motor 4.0 Turbo   91667.61
# Cadenza                                       Motor Diesel V6   93776.52
# Etios Sedã                              Motor 5.0 V8 Bi-Turbo   66433.82
# Alsvin                                        Motor Diesel V8  109059.27
# Cadillac ATS                                  Motor Diesel V6  122069.97
# Série 3 M3 Sedã                               Motor Diesel V6  113090.32
# Classe S                                        Motor 3.0 32v   89401.10
# T6                                              Motor 3.0 32v   56842.79
# Aston Martin DB7                              Motor Diesel V8  146676.71
# 207 Sedan                                     Motor 4.0 Turbo   89511.96
# Aston Martin Virage                              Motor Diesel   97290.18
# Azera                                           Motor 1.8 16v  120673.56
# Vantage Volante                               Motor Diesel V8  114434.94
# Siena EL                                             Motor V8  139546.69
# Palio Adventure                               Motor Diesel V8   95078.16
# HB20X                                                Motor V8   68091.77
# HR                                      Motor 5.0 V8 Bi-Turbo   61496.97
# Cadillac STS V-Series                           Motor 2.0 16v  139669.30
# Série 1 Coupé                                    Motor 1.0 8v   80661.39
# SpaceFox                                             Motor V8   61783.65
# C30                                              Motor 1.0 8v   52805.91
# J3 Turin                                             Motor V6  127024.75
# Classe B                                      Motor Diesel V8  135543.00
# Parati                                        Motor Diesel V8  121708.73
# Cadillac CTS V-Series                         Motor 4.0 Turbo  107342.68
# Sedan                                                Motor V8   57888.10
# Classe CLS 63 AMG                             Motor Diesel V6  118161.48
# Aircross                                         Motor 1.0 8v  142499.06
# Aston Martin V12 Vantage                             Motor V8  128396.11
# Sandero                                          Motor Diesel  112350.61
# New Fiesta                              Motor 5.0 V8 Bi-Turbo  124661.38
# XKR                                              Motor Diesel   54263.16
# X5                                               Motor Diesel   62041.32
# Cadillac DTS                                    Motor 1.8 16v  129296.11
# Pajero Dakar                                  Motor 4.0 Turbo   60998.33
# Classe A                                         Motor 1.0 8v   58008.50
# Ford Focus Fastback                           Motor 4.0 Turbo   82304.19
# Partner                                       Motor 2.4 Turbo  114531.74
# R8                                                   Motor V6  128565.61
# Aston Martin DBS Volante                      Motor 4.0 Turbo  126488.26
# Mohave                                        Motor Diesel V6  119074.55
# Fusca                                           Motor 3.0 32v  130238.04
# Chana Family                                         Motor V8  115760.17
# XC40                                          Motor 2.4 Turbo  121248.00
# Phantom I Jonckheere Aerodynamic Coupe          Motor 1.8 16v   98156.35
# Boxer                                                Motor V6  112146.80
# Chana Cargo                                     Motor 2.0 16v  102729.63
# Dodge Dakota                                     Motor Diesel  141083.35
# X1                                            Motor Diesel V8  102968.76
# GLA                                              Motor 1.0 8v   76310.01
# Range Rover Sport                                Motor 1.0 8v  120481.74
# DS3                                             Motor 1.8 16v   54559.18
# Veracruz                                      Motor Diesel V8   92957.64
# Cadillac CTS coupe, sedan, and wagon                 Motor V8  127810.06
# i30 CW                                           Motor Diesel   73311.75
# Phantom III                                   Motor Diesel V6   65138.03
# A3 Sedan                                             Motor V6   90141.47
# Aston Martin DB9 Volante                        Motor 2.0 16v   71160.36
# Série 7 Sedã                                     Motor Diesel   67539.79
# Lamborghini Reventón                          Motor 4.0 Turbo   67664.86
# Grand Livina                                    Motor 2.0 16v   68652.16
# V60                                              Motor Diesel  114728.74
# Effa Hafei Picape Cabine Dupla                       Motor V6  141645.08
# Benni Mini                                           Motor V8  126247.84
# Uno                                           Motor Diesel V6  128852.21
# L200 Savana                                     Motor 2.0 16v  132384.76
# Santa Fe                                        Motor 3.0 32v  129415.33
# RS5                                                  Motor V6   89536.82
# Cerato                                               Motor V6   87975.30
# XC60                                          Motor 4.0 Turbo   77675.79
# LS 460L                                       Motor Diesel V8   58881.67
# Lamborghini Sesto Elemento                           Motor V8   55081.99
# Lamborghini Huracán                                  Motor V8  118826.44
# A7                                               Motor 1.0 8v  137627.62
# Phantom 2013                                         Motor V8   51759.58
# Cadillac Ciel concept                                Motor V8   51667.06
# Classe GLK                              Motor 5.0 V8 Bi-Turbo   68934.03
# Aston Martin DB5                                 Motor Diesel  122110.90
# Macan                                         Motor Diesel V6   90381.47

# %% [markdown]
# ### Utilizando .iloc para seleções
#
# <font color=red>**Observação:**</font> Seleciona com base nos índices, ou seja, se baseia na posição das informações.

# %%
dataset.head()
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Jetta Variant     Motor 4.0 Turbo  ...   88078.64
# Passat               Motor Diesel  ...  106161.94
# Crossfox          Motor Diesel V8  ...   72832.16
# DS5               Motor 2.4 Turbo  ...  124549.07
# Aston Martin DB4  Motor 2.4 Turbo  ...   92612.10
#
# [5 rows x 6 columns]

# %%
dataset.iloc[[1]]
# Out:
#                Motor  ...      Valor
# Nome                  ...
# Passat  Motor Diesel  ...  106161.94
#
# [1 rows x 6 columns]

# %%
dataset.iloc[1:4]
# Out:
#                     Motor  ...      Valor
# Nome                       ...
# Passat       Motor Diesel  ...  106161.94
# Crossfox  Motor Diesel V8  ...   72832.16
# DS5       Motor 2.4 Turbo  ...  124549.07
#
# [3 rows x 6 columns]

# %%
dataset.iloc[1:4, [0,5,2]]
# Out:
#                     Motor      Valor  Quilometragem
# Nome
# Passat       Motor Diesel  106161.94         5712.0
# Crossfox  Motor Diesel V8   72832.16        37123.0
# DS5       Motor 2.4 Turbo  124549.07            NaN

# %% [markdown]
# # 5.3 Queries com DataFrames

# %%
dataset.Motor
# Out:
# Nome
# Jetta Variant                                   Motor 4.0 Turbo
# Passat                                             Motor Diesel
# Crossfox                                        Motor Diesel V8
# DS5                                             Motor 2.4 Turbo
# Aston Martin DB4                                Motor 2.4 Turbo
# Palio Weekend                                     Motor 1.8 16v
# A5                                              Motor 4.0 Turbo
# Série 3 Cabrio                                     Motor 1.0 8v
# Dodge Jorney                                      Motor 3.0 32v
# Carens                                    Motor 5.0 V8 Bi-Turbo
# Ford Edge                                       Motor Diesel V6
# Courier                                         Motor Diesel V8
# S-18                                                   Motor V6
# J5                                                     Motor V6
# F-Type Coupé                              Motor 5.0 V8 Bi-Turbo
# RAM                                             Motor Diesel V8
# Série 1                                           Motor 3.0 32v
# A3                                                 Motor 1.0 8v
# XC90                                               Motor 1.0 8v
# RS 3 Sportback                                    Motor 3.0 32v
# Pajero Sport                                       Motor 1.0 8v
# Série 1 M                                              Motor V8
# Lamborghini Obvious                             Motor Diesel V6
# Effa Hafei Picape Baú                              Motor Diesel
# Lamborghini Murciélago                    Motor 5.0 V8 Bi-Turbo
# Up!                                             Motor Diesel V6
# Fiesta Rocam Sedan                              Motor 4.0 Turbo
# Sandero Stepway                                   Motor 3.0 32v
# Cayman S                                          Motor 3.0 32v
# V40                                             Motor 4.0 Turbo
# Classe SLS AMG                                     Motor 1.0 8v
# Gol G4                                            Motor 2.0 16v
# Linea                                              Motor 1.0 8v
# Ford F100                                         Motor 2.0 16v
# J2                                                     Motor V8
# Aston Martin DBS                                       Motor V8
# Pajero TR4                                      Motor 2.4 Turbo
# Polo Sedan                                             Motor V6
# California                                         Motor 1.0 8v
# S60                                             Motor 2.4 Turbo
# Tucson                                            Motor 2.0 16v
# HB20                                                   Motor V6
# Optima                                            Motor 1.8 16v
# Logan                                           Motor 4.0 Turbo
# Range Rover Vogue                                  Motor 1.0 8v
# Sonata                                    Motor 5.0 V8 Bi-Turbo
# Ford New Fiesta Sedan                             Motor 3.0 32v
# Série 5 Gran Turismo                            Motor 4.0 Turbo
# CR-V                                            Motor Diesel V8
# Ford EcoSport                                      Motor 1.0 8v
# Versa                                             Motor 3.0 32v
# Classe E                                           Motor 1.0 8v
# Carnival                                               Motor V8
# Aston Martin V8 Vantage Roadster                Motor 2.4 Turbo
# Hoggar                                    Motor 5.0 V8 Bi-Turbo
# A1                                        Motor 5.0 V8 Bi-Turbo
# Aston Martin DB7 Vantage                               Motor V6
# CLA                                                Motor 1.0 8v
# Accord                                                 Motor V8
# EXTRA 103EX                                       Motor 2.0 16v
# Sorento                                            Motor Diesel
# Tiggo                                             Motor 3.0 32v
# New Fiesta Hatch                                   Motor Diesel
# Jeep Renegade                             Motor 5.0 V8 Bi-Turbo
# Lamborghini Ankonian                              Motor 2.0 16v
# Space Cross                               Motor 5.0 V8 Bi-Turbo
# Touareg                                                Motor V8
# Classe M                                           Motor 1.0 8v
# Lancer Evolution X                              Motor Diesel V6
# Kangoo Express                                     Motor Diesel
# SW4                                             Motor Diesel V6
# Cadillac ELR                                       Motor 1.0 8v
# Doblò                                             Motor 1.8 16v
# Lamborghini Egoista                               Motor 3.0 32v
# Fit                                                Motor Diesel
# C5                                                Motor 2.0 16v
# Celer Hatch                                            Motor V8
# HB20S                                                  Motor V8
# Cielo Hatch                                        Motor Diesel
# Livina                                            Motor 2.0 16v
# Ducato                                    Motor 5.0 V8 Bi-Turbo
# March                                                  Motor V6
# Cadillac XTS sedan                              Motor Diesel V6
# Lamborghini Centenario                                 Motor V6
# Hilux                                     Motor 5.0 V8 Bi-Turbo
# Grand Siena                                     Motor Diesel V8
# Symbol                                             Motor Diesel
# Aston Martin V12 GT Zagato                      Motor 4.0 Turbo
# Fusion                                            Motor 1.8 16v
# A4 Sedan                                           Motor Diesel
# Xsara Picasso                                     Motor 2.0 16v
# 207 SW                                            Motor 3.0 32v
# Star                                                   Motor V6
# Doblò Cargo                                       Motor 3.0 32v
# Cadillac CTS                                      Motor 1.8 16v
# Cayenne                                            Motor 1.0 8v
# Fox                                             Motor 4.0 Turbo
# Tiida Hatch                                     Motor Diesel V6
# Dodge Charger                                   Motor 2.4 Turbo
# Face                                                   Motor V8
# Prius                                             Motor 3.0 32v
# Idea                                                   Motor V6
# A8                                                Motor 2.0 16v
# Série 1 Cabrio                                    Motor 3.0 32v
# Edge                                                   Motor V6
# Cadillac ATS sedan                                Motor 1.8 16v
# Lamborghini Asterion LPI 910-4            Motor 5.0 V8 Bi-Turbo
# Frontier                                               Motor V8
# Série 3 Sedã                                      Motor 3.0 32v
# Lamborghini LM002                                 Motor 1.8 16v
# Cadillac XLR                                    Motor Diesel V8
# A4 Avant                                           Motor Diesel
# EcoSport                                        Motor 4.0 Turbo
# J3                                                Motor 1.8 16v
# Q3                                                Motor 3.0 32v
# Aston Martin V8 Vantage                                Motor V8
# Z4 Roadster                                       Motor 3.0 32v
# Lamborghini Ferruccio                             Motor 3.0 32v
# Ford Ka+                                          Motor 1.8 16v
# Silver Shadow                                      Motor Diesel
# Classe C 63 AMG Touring                         Motor Diesel V8
# Discovery 4                                     Motor 4.0 Turbo
# Veloster                                        Motor Diesel V8
# Classe C                                        Motor Diesel V6
# Camry                                              Motor Diesel
# C5 Tourer                                       Motor Diesel V6
# R8 GT                                           Motor 4.0 Turbo
# Bongo                                           Motor Diesel V8
# ASX                                             Motor Diesel V8
# Cadillac SRX                              Motor 5.0 V8 Bi-Turbo
# Classe CL                                              Motor V8
# 500 Abarth                                             Motor V6
# Aston Martin Cygnet                       Motor 5.0 V8 Bi-Turbo
# Cadillac STS                                    Motor 4.0 Turbo
# Aston Martin DB9                                  Motor 1.8 16v
# NX 200t                                         Motor 2.4 Turbo
# Aston Martin One-77                                    Motor V6
# Lamborghini Veneno                                Motor 3.0 32v
# Sentra                                            Motor 2.0 16v
# Jumper                                          Motor 2.4 Turbo
# i30                                               Motor 1.8 16v
# X6                                              Motor Diesel V6
# Voyage                                    Motor 5.0 V8 Bi-Turbo
# Phantom I Phantom II                              Motor 1.8 16v
# Passat Variant                                     Motor 1.0 8v
# Clio                                               Motor Diesel
# Classe G                                        Motor Diesel V6
# Silver Ghost                                      Motor 1.8 16v
# Série 3 M3 Coupé                                   Motor Diesel
# Gallardo LP 560 – 4                                Motor Diesel
# Freelander 2                                    Motor Diesel V6
# Grand Cherokee                            Motor 5.0 V8 Bi-Turbo
# Aston Martin DBR9                               Motor 4.0 Turbo
# Soul                                      Motor 5.0 V8 Bi-Turbo
# Cadillac BLS                                           Motor V8
# RX 350                                                 Motor V6
# Cayman                                            Motor 3.0 32v
# Chana Utility                                      Motor Diesel
# 308 CC                                          Motor 4.0 Turbo
# L200 Triton                                     Motor Diesel V8
# Jetta                                     Motor 5.0 V8 Bi-Turbo
# C4 Lounge                                              Motor V8
# C4 Pallas                                          Motor 1.0 8v
# Equus                                             Motor 3.0 32v
# Classe GL                                         Motor 3.0 32v
# Range Rover Evoque                                Motor 2.0 16v
# Cherokee                                        Motor 4.0 Turbo
# Punto                                           Motor 4.0 Turbo
# Grand Tour                                        Motor 3.0 32v
# Fluence                                         Motor Diesel V6
# Effa Hafei Picape Cabine Simples                   Motor 1.0 8v
# Durango                                           Motor 2.0 16v
# Boxster                                         Motor Diesel V8
# TT Roadster                                        Motor Diesel
# Lamborghini Jalpa                                 Motor 1.8 16v
# Classe SLK                                      Motor 4.0 Turbo
# Golf                                               Motor 1.0 8v
# C3 Picasso                                        Motor 3.0 32v
# V50                                               Motor 2.0 16v
# Picanto                                         Motor 4.0 Turbo
# Cadenza                                         Motor Diesel V6
# Etios Sedã                                Motor 5.0 V8 Bi-Turbo
# Alsvin                                          Motor Diesel V8
# Cadillac ATS                                    Motor Diesel V6
# Série 3 M3 Sedã                                 Motor Diesel V6
# Classe S                                          Motor 3.0 32v
# T6                                                Motor 3.0 32v
# Aston Martin DB7                                Motor Diesel V8
# 207 Sedan                                       Motor 4.0 Turbo
# Aston Martin Virage                                Motor Diesel
# Azera                                             Motor 1.8 16v
# Vantage Volante                                 Motor Diesel V8
# Siena EL                                               Motor V8
# Palio Adventure                                 Motor Diesel V8
# HB20X                                                  Motor V8
# HR                                        Motor 5.0 V8 Bi-Turbo
# Cadillac STS V-Series                             Motor 2.0 16v
# Série 1 Coupé                                      Motor 1.0 8v
# SpaceFox                                               Motor V8
# C30                                                Motor 1.0 8v
# J3 Turin                                               Motor V6
# Classe B                                        Motor Diesel V8
# Parati                                          Motor Diesel V8
# Cadillac CTS V-Series                           Motor 4.0 Turbo
# Sedan                                                  Motor V8
# Classe CLS 63 AMG                               Motor Diesel V6
# Aircross                                           Motor 1.0 8v
# Aston Martin V12 Vantage                               Motor V8
# Sandero                                            Motor Diesel
# New Fiesta                                Motor 5.0 V8 Bi-Turbo
# XKR                                                Motor Diesel
# X5                                                 Motor Diesel
# Cadillac DTS                                      Motor 1.8 16v
# Pajero Dakar                                    Motor 4.0 Turbo
# Classe A                                           Motor 1.0 8v
# Ford Focus Fastback                             Motor 4.0 Turbo
# Partner                                         Motor 2.4 Turbo
# R8                                                     Motor V6
# Aston Martin DBS Volante                        Motor 4.0 Turbo
# Mohave                                          Motor Diesel V6
# Fusca                                             Motor 3.0 32v
# Chana Family                                           Motor V8
# XC40                                            Motor 2.4 Turbo
# Phantom I Jonckheere Aerodynamic Coupe            Motor 1.8 16v
# Boxer                                                  Motor V6
# Chana Cargo                                       Motor 2.0 16v
# Dodge Dakota                                       Motor Diesel
# X1                                              Motor Diesel V8
# GLA                                                Motor 1.0 8v
# Range Rover Sport                                  Motor 1.0 8v
# DS3                                               Motor 1.8 16v
# Veracruz                                        Motor Diesel V8
# Cadillac CTS coupe, sedan, and wagon                   Motor V8
# i30 CW                                             Motor Diesel
# Phantom III                                     Motor Diesel V6
# A3 Sedan                                               Motor V6
# Aston Martin DB9 Volante                          Motor 2.0 16v
# Série 7 Sedã                                       Motor Diesel
# Lamborghini Reventón                            Motor 4.0 Turbo
# Grand Livina                                      Motor 2.0 16v
# V60                                                Motor Diesel
# Effa Hafei Picape Cabine Dupla                         Motor V6
# Benni Mini                                             Motor V8
# Uno                                             Motor Diesel V6
# L200 Savana                                       Motor 2.0 16v
# Santa Fe                                          Motor 3.0 32v
# RS5                                                    Motor V6
# Cerato                                                 Motor V6
# XC60                                            Motor 4.0 Turbo
# LS 460L                                         Motor Diesel V8
# Lamborghini Sesto Elemento                             Motor V8
# Lamborghini Huracán                                    Motor V8
# A7                                                 Motor 1.0 8v
# Phantom 2013                                           Motor V8
# Cadillac Ciel concept                                  Motor V8
# Classe GLK                                Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                                   Motor Diesel
# Macan                                           Motor Diesel V6
# Name: Motor, dtype: object

# %%
#Query no Pandas
select = dataset.Motor == 'Motor Diesel'

# %%
dataset[select]
# Out:
#                               Motor  ...      Valor
# Nome                                 ...
# Passat                 Motor Diesel  ...  106161.94
# Effa Hafei Picape Baú  Motor Diesel  ...  125684.65
# Sorento                Motor Diesel  ...   81399.35
# New Fiesta Hatch       Motor Diesel  ...   66007.16
# Kangoo Express         Motor Diesel  ...  146716.91
# Fit                    Motor Diesel  ...   77836.23
# Cielo Hatch            Motor Diesel  ...  145197.70
# Symbol                 Motor Diesel  ...  133030.60
# A4 Sedan               Motor Diesel  ...   96369.04
# A4 Avant               Motor Diesel  ...  138946.88
# Silver Shadow          Motor Diesel  ...  143568.22
# Camry                  Motor Diesel  ...  138597.27
# Clio                   Motor Diesel  ...  111130.33
# Série 3 M3 Coupé       Motor Diesel  ...   69219.89
# Gallardo LP 560 – 4    Motor Diesel  ...  144118.91
# Chana Utility          Motor Diesel  ...  132662.32
# TT Roadster            Motor Diesel  ...   85311.40
# Aston Martin Virage    Motor Diesel  ...   97290.18
# Sandero                Motor Diesel  ...  112350.61
# XKR                    Motor Diesel  ...   54263.16
# X5                     Motor Diesel  ...   62041.32
# Dodge Dakota           Motor Diesel  ...  141083.35
# i30 CW                 Motor Diesel  ...   73311.75
# Série 7 Sedã           Motor Diesel  ...   67539.79
# V60                    Motor Diesel  ...  114728.74
# Aston Martin DB5       Motor Diesel  ...  122110.90
#
# [26 rows x 6 columns]

# %%
#Query que localiza carros com Motor a Diesel e que sejam 0 KM

dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km == True)]
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Sorento              Motor Diesel  ...   81399.35
# Cielo Hatch          Motor Diesel  ...  145197.70
# Camry                Motor Diesel  ...  138597.27
# Aston Martin Virage  Motor Diesel  ...   97290.18
# Série 7 Sedã         Motor Diesel  ...   67539.79
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Utilizando o método query

# %%
#Query que localiza carros com Motor a Diesel e que sejam 0 KM, mas de uma forma menos verbosa que a anterior

dataset.query('Motor == "Motor Diesel" and Zero_km')
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Sorento              Motor Diesel  ...   81399.35
# Cielo Hatch          Motor Diesel  ...  145197.70
# Camry                Motor Diesel  ...  138597.27
# Aston Martin Virage  Motor Diesel  ...   97290.18
# Série 7 Sedã         Motor Diesel  ...   67539.79
#
# [5 rows x 6 columns]

# %% [markdown]
# # 5.4 Iterando com DataFrames

# %%
dataset.head()
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Jetta Variant     Motor 4.0 Turbo  ...   88078.64
# Passat               Motor Diesel  ...  106161.94
# Crossfox          Motor Diesel V8  ...   72832.16
# DS5               Motor 2.4 Turbo  ...  124549.07
# Aston Martin DB4  Motor 2.4 Turbo  ...   92612.10
#
# [5 rows x 6 columns]

# %%
for i in dataset:
  print(i)
# Out:
# Motor
# Ano
# Quilometragem
# Zero_km
# Acessórios
# Valor

# %%
for index, row in dataset.iterrows():
  if(2019 - row['Ano'] != 0):
    dataset.loc[index, 'Km_media'] = row['Quilometragem'] / (2019 - row['Ano'])
  else:
    dataset.loc[index, 'Km_media'] = 0

dataset
# Out:
#                                                         Motor  ...      Km_media
# Nome                                                           ...
# Jetta Variant                                 Motor 4.0 Turbo  ...   2775.625000
# Passat                                           Motor Diesel  ...    204.000000
# Crossfox                                      Motor Diesel V8  ...   1280.103448
# DS5                                           Motor 2.4 Turbo  ...      0.000000
# Aston Martin DB4                              Motor 2.4 Turbo  ...   1981.307692
# Palio Weekend                                   Motor 1.8 16v  ...   1532.571429
# A5                                            Motor 4.0 Turbo  ...      0.000000
# Série 3 Cabrio                                   Motor 1.0 8v  ...   7759.900000
# Dodge Jorney                                    Motor 3.0 32v  ...  11021.888889
# Carens                                  Motor 5.0 V8 Bi-Turbo  ...   4747.250000
# Ford Edge                                     Motor Diesel V6  ...    756.411765
# Courier                                       Motor Diesel V8  ...    671.000000
# S-18                                                 Motor V6  ...   4987.388889
# J5                                                   Motor V6  ...      0.000000
# F-Type Coupé                            Motor 5.0 V8 Bi-Turbo  ...   4145.700000
# RAM                                           Motor Diesel V8  ...  38535.666667
# Série 1                                         Motor 3.0 32v  ...   6635.571429
# A3                                               Motor 1.0 8v  ...      0.000000
# XC90                                             Motor 1.0 8v  ...  12362.000000
# RS 3 Sportback                                  Motor 3.0 32v  ...   7586.500000
# Pajero Sport                                     Motor 1.0 8v  ...   5952.529412
# Série 1 M                                            Motor V8  ...      0.000000
# Lamborghini Obvious                           Motor Diesel V6  ...   3923.160000
# Effa Hafei Picape Baú                            Motor Diesel  ...   3677.107143
# Lamborghini Murciélago                  Motor 5.0 V8 Bi-Turbo  ...      0.000000
# Up!                                           Motor Diesel V6  ...      0.000000
# Fiesta Rocam Sedan                            Motor 4.0 Turbo  ...   1931.666667
# Sandero Stepway                                 Motor 3.0 32v  ...      0.000000
# Cayman S                                        Motor 3.0 32v  ...   3461.647059
# V40                                           Motor 4.0 Turbo  ...   3370.750000
# Classe SLS AMG                                   Motor 1.0 8v  ...   1371.045455
# Gol G4                                          Motor 2.0 16v  ...   2222.166667
# Linea                                            Motor 1.0 8v  ...  17720.000000
# Ford F100                                       Motor 2.0 16v  ...   1207.428571
# J2                                                   Motor V8  ...  18136.800000
# Aston Martin DBS                                     Motor V8  ...   1832.291667
# Pajero TR4                                    Motor 2.4 Turbo  ...      0.000000
# Polo Sedan                                           Motor V6  ...      0.000000
# California                                       Motor 1.0 8v  ...    552.600000
# S60                                           Motor 2.4 Turbo  ...      0.000000
# Tucson                                          Motor 2.0 16v  ...  15569.166667
# HB20                                                 Motor V6  ...   2547.625000
# Optima                                          Motor 1.8 16v  ...      0.000000
# Logan                                         Motor 4.0 Turbo  ...   5076.588235
# Range Rover Vogue                                Motor 1.0 8v  ...      0.000000
# Sonata                                  Motor 5.0 V8 Bi-Turbo  ...    573.823529
# Ford New Fiesta Sedan                           Motor 3.0 32v  ...   4663.000000
# Série 5 Gran Turismo                          Motor 4.0 Turbo  ...    133.055556
# CR-V                                          Motor Diesel V8  ...      0.000000
# Ford EcoSport                                    Motor 1.0 8v  ...   5021.812500
# Versa                                           Motor 3.0 32v  ...   8555.400000
# Classe E                                         Motor 1.0 8v  ...   3884.307692
# Carnival                                             Motor V8  ...   3564.000000
# Aston Martin V8 Vantage Roadster              Motor 2.4 Turbo  ...   7226.692308
# Hoggar                                  Motor 5.0 V8 Bi-Turbo  ...   3927.222222
# A1                                      Motor 5.0 V8 Bi-Turbo  ...   3240.280000
# Aston Martin DB7 Vantage                             Motor V6  ...   9959.416667
# CLA                                              Motor 1.0 8v  ...      0.000000
# Accord                                               Motor V8  ...      0.000000
# EXTRA 103EX                                     Motor 2.0 16v  ...      0.000000
# Sorento                                          Motor Diesel  ...      0.000000
# Tiggo                                           Motor 3.0 32v  ...      0.000000
# New Fiesta Hatch                                 Motor Diesel  ...  59447.500000
# Jeep Renegade                           Motor 5.0 V8 Bi-Turbo  ...   6063.625000
# Lamborghini Ankonian                            Motor 2.0 16v  ...   5606.222222
# Space Cross                             Motor 5.0 V8 Bi-Turbo  ...   4158.652174
# Touareg                                              Motor V8  ...      0.000000
# Classe M                                         Motor 1.0 8v  ...   3619.800000
# Lancer Evolution X                            Motor Diesel V6  ...      0.000000
# Kangoo Express                                   Motor Diesel  ...   2427.666667
# SW4                                           Motor Diesel V6  ...    952.080000
# Cadillac ELR                                     Motor 1.0 8v  ...   7082.666667
# Doblò                                           Motor 1.8 16v  ...   2472.500000
# Lamborghini Egoista                             Motor 3.0 32v  ...   2056.230769
# Fit                                              Motor Diesel  ...   7388.166667
# C5                                              Motor 2.0 16v  ...   4729.440000
# Celer Hatch                                          Motor V8  ...  10346.181818
# HB20S                                                Motor V8  ...     55.454545
# Cielo Hatch                                      Motor Diesel  ...      0.000000
# Livina                                          Motor 2.0 16v  ...      0.000000
# Ducato                                  Motor 5.0 V8 Bi-Turbo  ...    644.350000
# March                                                Motor V6  ...   6633.916667
# Cadillac XTS sedan                            Motor Diesel V6  ...   3497.076923
# Lamborghini Centenario                               Motor V6  ...   1780.541667
# Hilux                                   Motor 5.0 V8 Bi-Turbo  ...      0.000000
# Grand Siena                                   Motor Diesel V8  ...      0.000000
# Symbol                                           Motor Diesel  ...  39238.000000
# Aston Martin V12 GT Zagato                    Motor 4.0 Turbo  ...  14235.625000
# Fusion                                          Motor 1.8 16v  ...      0.000000
# A4 Sedan                                         Motor Diesel  ...   1794.764706
# Xsara Picasso                                   Motor 2.0 16v  ...  12477.833333
# 207 SW                                          Motor 3.0 32v  ...  59880.000000
# Star                                                 Motor V6  ...   2785.333333
# Doblò Cargo                                     Motor 3.0 32v  ...   5840.636364
# Cadillac CTS                                    Motor 1.8 16v  ...  88661.000000
# Cayenne                                          Motor 1.0 8v  ...    283.687500
# Fox                                           Motor 4.0 Turbo  ...   6882.250000
# Tiida Hatch                                   Motor Diesel V6  ...   2214.333333
# Dodge Charger                                 Motor 2.4 Turbo  ...  10222.333333
# Face                                                 Motor V8  ...      0.000000
# Prius                                           Motor 3.0 32v  ...   6285.230769
# Idea                                                 Motor V6  ...   3924.500000
# A8                                              Motor 2.0 16v  ...      0.000000
# Série 1 Cabrio                                  Motor 3.0 32v  ...  22819.250000
# Edge                                                 Motor V6  ...  26544.000000
# Cadillac ATS sedan                              Motor 1.8 16v  ...  26298.000000
# Lamborghini Asterion LPI 910-4          Motor 5.0 V8 Bi-Turbo  ...   1759.370370
# Frontier                                             Motor V8  ...   4947.555556
# Série 3 Sedã                                    Motor 3.0 32v  ...   1109.000000
# Lamborghini LM002                               Motor 1.8 16v  ...   4606.833333
# Cadillac XLR                                  Motor Diesel V8  ...   3539.875000
# A4 Avant                                         Motor Diesel  ...   3471.400000
# EcoSport                                      Motor 4.0 Turbo  ...   6728.636364
# J3                                              Motor 1.8 16v  ...   2532.666667
# Q3                                              Motor 3.0 32v  ...      0.000000
# Aston Martin V8 Vantage                              Motor V8  ...   5410.500000
# Z4 Roadster                                     Motor 3.0 32v  ...      0.000000
# Lamborghini Ferruccio                           Motor 3.0 32v  ...      0.000000
# Ford Ka+                                        Motor 1.8 16v  ...    738.076923
# Silver Shadow                                    Motor Diesel  ...  24763.000000
# Classe C 63 AMG Touring                       Motor Diesel V8  ...   4365.750000
# Discovery 4                                   Motor 4.0 Turbo  ...   8567.500000
# Veloster                                      Motor Diesel V8  ...  48002.500000
# Classe C                                      Motor Diesel V6  ...   1506.619048
# Camry                                            Motor Diesel  ...      0.000000
# C5 Tourer                                     Motor Diesel V6  ...   4009.350000
# R8 GT                                         Motor 4.0 Turbo  ...      0.000000
# Bongo                                         Motor Diesel V8  ...   5821.200000
# ASX                                           Motor Diesel V8  ...   3854.500000
# Cadillac SRX                            Motor 5.0 V8 Bi-Turbo  ...   1280.680000
# Classe CL                                            Motor V8  ...      0.000000
# 500 Abarth                                           Motor V6  ...   2277.760000
# Aston Martin Cygnet                     Motor 5.0 V8 Bi-Turbo  ...      0.000000
# Cadillac STS                                  Motor 4.0 Turbo  ...  21629.750000
# Aston Martin DB9                                Motor 1.8 16v  ...    209.608696
# NX 200t                                       Motor 2.4 Turbo  ...   4592.045455
# Aston Martin One-77                                  Motor V6  ...   1180.961538
# Lamborghini Veneno                              Motor 3.0 32v  ...      0.000000
# Sentra                                          Motor 2.0 16v  ...   1205.740741
# Jumper                                        Motor 2.4 Turbo  ...   4307.875000
# i30                                             Motor 1.8 16v  ...      0.000000
# X6                                            Motor Diesel V6  ...   1906.517241
# Voyage                                  Motor 5.0 V8 Bi-Turbo  ...      0.000000
# Phantom I Phantom II                            Motor 1.8 16v  ...      0.000000
# Passat Variant                                   Motor 1.0 8v  ...   4140.357143
# Clio                                             Motor Diesel  ...   2290.931034
# Classe G                                      Motor Diesel V6  ...  13828.571429
# Silver Ghost                                    Motor 1.8 16v  ...   1186.416667
# Série 3 M3 Coupé                                 Motor Diesel  ...   3316.000000
# Gallardo LP 560 – 4                              Motor Diesel  ...   5949.736842
# Freelander 2                                  Motor Diesel V6  ...   6761.294118
# Grand Cherokee                          Motor 5.0 V8 Bi-Turbo  ...    137.956522
# Aston Martin DBR9                             Motor 4.0 Turbo  ...   3635.260870
# Soul                                    Motor 5.0 V8 Bi-Turbo  ...   6339.000000
# Cadillac BLS                                         Motor V8  ...   3409.000000
# RX 350                                               Motor V6  ...    385.666667
# Cayman                                          Motor 3.0 32v  ...    437.833333
# Chana Utility                                    Motor Diesel  ...   5203.400000
# 308 CC                                        Motor 4.0 Turbo  ...      0.000000
# L200 Triton                                   Motor Diesel V8  ...      0.000000
# Jetta                                   Motor 5.0 V8 Bi-Turbo  ...   4681.000000
# C4 Lounge                                            Motor V8  ...   4918.227273
# C4 Pallas                                        Motor 1.0 8v  ...   3640.619048
# Equus                                           Motor 3.0 32v  ...   3845.533333
# Classe GL                                       Motor 3.0 32v  ...   4200.434783
# Range Rover Evoque                              Motor 2.0 16v  ...  27250.250000
# Cherokee                                      Motor 4.0 Turbo  ...   8737.333333
# Punto                                         Motor 4.0 Turbo  ...   3283.642857
# Grand Tour                                      Motor 3.0 32v  ...   2459.100000
# Fluence                                       Motor Diesel V6  ...   2079.458333
# Effa Hafei Picape Cabine Simples                 Motor 1.0 8v  ...   1485.384615
# Durango                                         Motor 2.0 16v  ...   4066.400000
# Boxster                                       Motor Diesel V8  ...  12319.000000
# TT Roadster                                      Motor Diesel  ...   5113.904762
# Lamborghini Jalpa                               Motor 1.8 16v  ...   9146.000000
# Classe SLK                                    Motor 4.0 Turbo  ...      0.000000
# Golf                                             Motor 1.0 8v  ...  17924.000000
# C3 Picasso                                      Motor 3.0 32v  ...      0.000000
# V50                                             Motor 2.0 16v  ...   4032.724138
# Picanto                                       Motor 4.0 Turbo  ...   2047.600000
# Cadenza                                       Motor Diesel V6  ...   1820.827586
# Etios Sedã                              Motor 5.0 V8 Bi-Turbo  ...    680.692308
# Alsvin                                        Motor Diesel V8  ...   5395.529412
# Cadillac ATS                                  Motor Diesel V6  ...   1144.857143
# Série 3 M3 Sedã                               Motor Diesel V6  ...   2773.555556
# Classe S                                        Motor 3.0 32v  ...      0.000000
# T6                                              Motor 3.0 32v  ...      0.000000
# Aston Martin DB7                              Motor Diesel V8  ...   3727.785714
# 207 Sedan                                     Motor 4.0 Turbo  ...   9284.333333
# Aston Martin Virage                              Motor Diesel  ...      0.000000
# Azera                                           Motor 1.8 16v  ...   6776.000000
# Vantage Volante                               Motor Diesel V8  ...      0.000000
# Siena EL                                             Motor V8  ...   8397.444444
# Palio Adventure                               Motor Diesel V8  ...   1346.360000
# HB20X                                                Motor V8  ...   5796.722222
# HR                                      Motor 5.0 V8 Bi-Turbo  ...   5102.000000
# Cadillac STS V-Series                           Motor 2.0 16v  ...    824.565217
# Série 1 Coupé                                    Motor 1.0 8v  ...   3352.346154
# SpaceFox                                             Motor V8  ...    255.846154
# C30                                              Motor 1.0 8v  ...   3096.555556
# J3 Turin                                             Motor V6  ...      0.000000
# Classe B                                      Motor Diesel V8  ...      0.000000
# Parati                                        Motor Diesel V8  ...      0.000000
# Cadillac CTS V-Series                         Motor 4.0 Turbo  ...   5360.000000
# Sedan                                                Motor V8  ...      0.000000
# Classe CLS 63 AMG                             Motor Diesel V6  ...  22892.666667
# Aircross                                         Motor 1.0 8v  ...  14339.400000
# Aston Martin V12 Vantage                             Motor V8  ...      0.000000
# Sandero                                          Motor Diesel  ...   8695.750000
# New Fiesta                              Motor 5.0 V8 Bi-Turbo  ...   8443.000000
# XKR                                              Motor Diesel  ...   3701.173913
# X5                                               Motor Diesel  ...    800.352941
# Cadillac DTS                                    Motor 1.8 16v  ...   2546.214286
# Pajero Dakar                                  Motor 4.0 Turbo  ...   3963.666667
# Classe A                                         Motor 1.0 8v  ...    702.300000
# Ford Focus Fastback                           Motor 4.0 Turbo  ...   2942.428571
# Partner                                       Motor 2.4 Turbo  ...      0.000000
# R8                                                   Motor V6  ...   4368.181818
# Aston Martin DBS Volante                      Motor 4.0 Turbo  ...   3582.758621
# Mohave                                        Motor Diesel V6  ...   2434.111111
# Fusca                                           Motor 3.0 32v  ...   4106.333333
# Chana Family                                         Motor V8  ...      0.000000
# XC40                                          Motor 2.4 Turbo  ...  55483.000000
# Phantom I Jonckheere Aerodynamic Coupe          Motor 1.8 16v  ...   1998.375000
# Boxer                                                Motor V6  ...   3812.071429
# Chana Cargo                                     Motor 2.0 16v  ...    839.750000
# Dodge Dakota                                     Motor Diesel  ...   2751.692308
# X1                                            Motor Diesel V8  ...      3.821429
# GLA                                              Motor 1.0 8v  ...    299.785714
# Range Rover Sport                                Motor 1.0 8v  ...   1886.272727
# DS3                                             Motor 1.8 16v  ...   6105.368421
# Veracruz                                      Motor Diesel V8  ...   8404.833333
# Cadillac CTS coupe, sedan, and wagon                 Motor V8  ...   5190.384615
# i30 CW                                           Motor Diesel  ...   2124.250000
# Phantom III                                   Motor Diesel V6  ...    401.818182
# A3 Sedan                                             Motor V6  ...      0.000000
# Aston Martin DB9 Volante                        Motor 2.0 16v  ...   2545.086957
# Série 7 Sedã                                     Motor Diesel  ...      0.000000
# Lamborghini Reventón                          Motor 4.0 Turbo  ...      0.000000
# Grand Livina                                    Motor 2.0 16v  ...  22403.200000
# V60                                              Motor Diesel  ...   6122.666667
# Effa Hafei Picape Cabine Dupla                       Motor V6  ...  10253.363636
# Benni Mini                                           Motor V8  ...      0.000000
# Uno                                           Motor Diesel V6  ...      0.000000
# L200 Savana                                     Motor 2.0 16v  ...   1327.571429
# Santa Fe                                        Motor 3.0 32v  ...      0.000000
# RS5                                                  Motor V6  ...   2394.913043
# Cerato                                               Motor V6  ...   6099.500000
# XC60                                          Motor 4.0 Turbo  ...      0.000000
# LS 460L                                       Motor Diesel V8  ...   9965.000000
# Lamborghini Sesto Elemento                           Motor V8  ...   7115.333333
# Lamborghini Huracán                                  Motor V8  ...   3924.320000
# A7                                               Motor 1.0 8v  ...   5940.000000
# Phantom 2013                                         Motor V8  ...   5501.000000
# Cadillac Ciel concept                                Motor V8  ...   1070.750000
# Classe GLK                              Motor 5.0 V8 Bi-Turbo  ...   3096.294118
# Aston Martin DB5                                 Motor Diesel  ...    334.130435
# Macan                                         Motor Diesel V6  ...   1858.814815
#
# [258 rows x 9 columns]

# %% [markdown]
# # 5.5 Tratamento de dados

# %%
dataset.head()
# Out:
#                             Motor   Ano  ...  km_media     Km_media
# Nome                                     ...
# Jetta Variant     Motor 4.0 Turbo  2003  ...       NaN  2775.625000
# Passat               Motor Diesel  1991  ...       NaN   204.000000
# Crossfox          Motor Diesel V8  1990  ...       NaN  1280.103448
# DS5               Motor 2.4 Turbo  2019  ...       0.0     0.000000
# Aston Martin DB4  Motor 2.4 Turbo  2006  ...       NaN  1981.307692
#
# [5 rows x 9 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  197 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_Media       197 non-null    float64
#  7   km_media       61 non-null     float64
#  8   Km_media       258 non-null    float64
# dtypes: bool(1), float64(5), int64(1), object(2)
# memory usage: 28.4+ KB

# %%
#Seleção de infos nulas

dataset.Quilometragem.isna()
# Out:
# Nome
# Jetta Variant                             False
# Passat                                    False
# Crossfox                                  False
# DS5                                        True
# Aston Martin DB4                          False
# Palio Weekend                             False
# A5                                         True
# Série 3 Cabrio                            False
# Dodge Jorney                              False
# Carens                                    False
# Ford Edge                                 False
# Courier                                   False
# S-18                                      False
# J5                                         True
# F-Type Coupé                              False
# RAM                                       False
# Série 1                                   False
# A3                                         True
# XC90                                      False
# RS 3 Sportback                            False
# Pajero Sport                              False
# Série 1 M                                  True
# Lamborghini Obvious                       False
# Effa Hafei Picape Baú                     False
# Lamborghini Murciélago                     True
# Up!                                        True
# Fiesta Rocam Sedan                        False
# Sandero Stepway                            True
# Cayman S                                  False
# V40                                       False
# Classe SLS AMG                            False
# Gol G4                                    False
# Linea                                     False
# Ford F100                                 False
# J2                                        False
# Aston Martin DBS                          False
# Pajero TR4                                 True
# Polo Sedan                                 True
# California                                False
# S60                                        True
# Tucson                                    False
# HB20                                      False
# Optima                                     True
# Logan                                     False
# Range Rover Vogue                          True
# Sonata                                    False
# Ford New Fiesta Sedan                     False
# Série 5 Gran Turismo                      False
# CR-V                                       True
# Ford EcoSport                             False
# Versa                                     False
# Classe E                                  False
# Carnival                                  False
# Aston Martin V8 Vantage Roadster          False
# Hoggar                                    False
# A1                                        False
# Aston Martin DB7 Vantage                  False
# CLA                                        True
# Accord                                     True
# EXTRA 103EX                                True
# Sorento                                    True
# Tiggo                                      True
# New Fiesta Hatch                          False
# Jeep Renegade                             False
# Lamborghini Ankonian                      False
# Space Cross                               False
# Touareg                                    True
# Classe M                                  False
# Lancer Evolution X                         True
# Kangoo Express                            False
# SW4                                       False
# Cadillac ELR                              False
# Doblò                                     False
# Lamborghini Egoista                       False
# Fit                                       False
# C5                                        False
# Celer Hatch                               False
# HB20S                                     False
# Cielo Hatch                                True
# Livina                                     True
# Ducato                                    False
# March                                     False
# Cadillac XTS sedan                        False
# Lamborghini Centenario                    False
# Hilux                                      True
# Grand Siena                                True
# Symbol                                    False
# Aston Martin V12 GT Zagato                False
# Fusion                                     True
# A4 Sedan                                  False
# Xsara Picasso                             False
# 207 SW                                    False
# Star                                      False
# Doblò Cargo                               False
# Cadillac CTS                              False
# Cayenne                                   False
# Fox                                       False
# Tiida Hatch                               False
# Dodge Charger                             False
# Face                                       True
# Prius                                     False
# Idea                                      False
# A8                                         True
# Série 1 Cabrio                            False
# Edge                                      False
# Cadillac ATS sedan                        False
# Lamborghini Asterion LPI 910-4            False
# Frontier                                  False
# Série 3 Sedã                              False
# Lamborghini LM002                         False
# Cadillac XLR                              False
# A4 Avant                                  False
# EcoSport                                  False
# J3                                        False
# Q3                                         True
# Aston Martin V8 Vantage                   False
# Z4 Roadster                                True
# Lamborghini Ferruccio                      True
# Ford Ka+                                  False
# Silver Shadow                             False
# Classe C 63 AMG Touring                   False
# Discovery 4                               False
# Veloster                                  False
# Classe C                                  False
# Camry                                      True
# C5 Tourer                                 False
# R8 GT                                      True
# Bongo                                     False
# ASX                                       False
# Cadillac SRX                              False
# Classe CL                                  True
# 500 Abarth                                False
# Aston Martin Cygnet                        True
# Cadillac STS                              False
# Aston Martin DB9                          False
# NX 200t                                   False
# Aston Martin One-77                       False
# Lamborghini Veneno                         True
# Sentra                                    False
# Jumper                                    False
# i30                                        True
# X6                                        False
# Voyage                                     True
# Phantom I Phantom II                       True
# Passat Variant                            False
# Clio                                      False
# Classe G                                  False
# Silver Ghost                              False
# Série 3 M3 Coupé                          False
# Gallardo LP 560 – 4                       False
# Freelander 2                              False
# Grand Cherokee                            False
# Aston Martin DBR9                         False
# Soul                                      False
# Cadillac BLS                              False
# RX 350                                    False
# Cayman                                    False
# Chana Utility                             False
# 308 CC                                     True
# L200 Triton                                True
# Jetta                                     False
# C4 Lounge                                 False
# C4 Pallas                                 False
# Equus                                     False
# Classe GL                                 False
# Range Rover Evoque                        False
# Cherokee                                  False
# Punto                                     False
# Grand Tour                                False
# Fluence                                   False
# Effa Hafei Picape Cabine Simples          False
# Durango                                   False
# Boxster                                   False
# TT Roadster                               False
# Lamborghini Jalpa                         False
# Classe SLK                                 True
# Golf                                      False
# C3 Picasso                                 True
# V50                                       False
# Picanto                                   False
# Cadenza                                   False
# Etios Sedã                                False
# Alsvin                                    False
# Cadillac ATS                              False
# Série 3 M3 Sedã                           False
# Classe S                                   True
# T6                                         True
# Aston Martin DB7                          False
# 207 Sedan                                 False
# Aston Martin Virage                        True
# Azera                                     False
# Vantage Volante                            True
# Siena EL                                  False
# Palio Adventure                           False
# HB20X                                     False
# HR                                        False
# Cadillac STS V-Series                     False
# Série 1 Coupé                             False
# SpaceFox                                  False
# C30                                       False
# J3 Turin                                   True
# Classe B                                   True
# Parati                                     True
# Cadillac CTS V-Series                     False
# Sedan                                      True
# Classe CLS 63 AMG                         False
# Aircross                                  False
# Aston Martin V12 Vantage                   True
# Sandero                                   False
# New Fiesta                                False
# XKR                                       False
# X5                                        False
# Cadillac DTS                              False
# Pajero Dakar                              False
# Classe A                                  False
# Ford Focus Fastback                       False
# Partner                                    True
# R8                                        False
# Aston Martin DBS Volante                  False
# Mohave                                    False
# Fusca                                     False
# Chana Family                               True
# XC40                                      False
# Phantom I Jonckheere Aerodynamic Coupe    False
# Boxer                                     False
# Chana Cargo                               False
# Dodge Dakota                              False
# X1                                        False
# GLA                                       False
# Range Rover Sport                         False
# DS3                                       False
# Veracruz                                  False
# Cadillac CTS coupe, sedan, and wagon      False
# i30 CW                                    False
# Phantom III                               False
# A3 Sedan                                   True
# Aston Martin DB9 Volante                  False
# Série 7 Sedã                               True
# Lamborghini Reventón                       True
# Grand Livina                              False
# V60                                       False
# Effa Hafei Picape Cabine Dupla            False
# Benni Mini                                 True
# Uno                                        True
# L200 Savana                               False
# Santa Fe                                   True
# RS5                                       False
# Cerato                                    False
# XC60                                       True
# LS 460L                                   False
# Lamborghini Sesto Elemento                False
# Lamborghini Huracán                       False
# A7                                        False
# Phantom 2013                              False
# Cadillac Ciel concept                     False
# Classe GLK                                False
# Aston Martin DB5                          False
# Macan                                     False
# Name: Quilometragem, dtype: bool

# %%
dataset[dataset.Quilometragem.isna()]
# Out:
#                                           Motor   Ano  ...  km_media  Km_media
# Nome                                                   ...
# DS5                             Motor 2.4 Turbo  2019  ...       0.0       0.0
# A5                              Motor 4.0 Turbo  2019  ...       0.0       0.0
# J5                                     Motor V6  2019  ...       0.0       0.0
# A3                                 Motor 1.0 8v  2019  ...       0.0       0.0
# Série 1 M                              Motor V8  2019  ...       0.0       0.0
# Lamborghini Murciélago    Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Up!                             Motor Diesel V6  2019  ...       0.0       0.0
# Sandero Stepway                   Motor 3.0 32v  2019  ...       0.0       0.0
# Pajero TR4                      Motor 2.4 Turbo  2019  ...       0.0       0.0
# Polo Sedan                             Motor V6  2019  ...       0.0       0.0
# S60                             Motor 2.4 Turbo  2019  ...       0.0       0.0
# Optima                            Motor 1.8 16v  2019  ...       0.0       0.0
# Range Rover Vogue                  Motor 1.0 8v  2019  ...       0.0       0.0
# CR-V                            Motor Diesel V8  2019  ...       0.0       0.0
# CLA                                Motor 1.0 8v  2019  ...       0.0       0.0
# Accord                                 Motor V8  2019  ...       0.0       0.0
# EXTRA 103EX                       Motor 2.0 16v  2019  ...       0.0       0.0
# Sorento                            Motor Diesel  2019  ...       0.0       0.0
# Tiggo                             Motor 3.0 32v  2019  ...       0.0       0.0
# Touareg                                Motor V8  2019  ...       0.0       0.0
# Lancer Evolution X              Motor Diesel V6  2019  ...       0.0       0.0
# Cielo Hatch                        Motor Diesel  2019  ...       0.0       0.0
# Livina                            Motor 2.0 16v  2019  ...       0.0       0.0
# Hilux                     Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Grand Siena                     Motor Diesel V8  2019  ...       0.0       0.0
# Fusion                            Motor 1.8 16v  2019  ...       0.0       0.0
# Face                                   Motor V8  2019  ...       0.0       0.0
# A8                                Motor 2.0 16v  2019  ...       0.0       0.0
# Q3                                Motor 3.0 32v  2019  ...       0.0       0.0
# Z4 Roadster                       Motor 3.0 32v  2019  ...       0.0       0.0
# Lamborghini Ferruccio             Motor 3.0 32v  2019  ...       0.0       0.0
# Camry                              Motor Diesel  2019  ...       0.0       0.0
# R8 GT                           Motor 4.0 Turbo  2019  ...       0.0       0.0
# Classe CL                              Motor V8  2019  ...       0.0       0.0
# Aston Martin Cygnet       Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Lamborghini Veneno                Motor 3.0 32v  2019  ...       0.0       0.0
# i30                               Motor 1.8 16v  2019  ...       0.0       0.0
# Voyage                    Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Phantom I Phantom II              Motor 1.8 16v  2019  ...       0.0       0.0
# 308 CC                          Motor 4.0 Turbo  2019  ...       0.0       0.0
# L200 Triton                     Motor Diesel V8  2019  ...       0.0       0.0
# Classe SLK                      Motor 4.0 Turbo  2019  ...       0.0       0.0
# C3 Picasso                        Motor 3.0 32v  2019  ...       0.0       0.0
# Classe S                          Motor 3.0 32v  2019  ...       0.0       0.0
# T6                                Motor 3.0 32v  2019  ...       0.0       0.0
# Aston Martin Virage                Motor Diesel  2019  ...       0.0       0.0
# Vantage Volante                 Motor Diesel V8  2019  ...       0.0       0.0
# J3 Turin                               Motor V6  2019  ...       0.0       0.0
# Classe B                        Motor Diesel V8  2019  ...       0.0       0.0
# Parati                          Motor Diesel V8  2019  ...       0.0       0.0
# Sedan                                  Motor V8  2019  ...       0.0       0.0
# Aston Martin V12 Vantage               Motor V8  2019  ...       0.0       0.0
# Partner                         Motor 2.4 Turbo  2019  ...       0.0       0.0
# Chana Family                           Motor V8  2019  ...       0.0       0.0
# A3 Sedan                               Motor V6  2019  ...       0.0       0.0
# Série 7 Sedã                       Motor Diesel  2019  ...       0.0       0.0
# Lamborghini Reventón            Motor 4.0 Turbo  2019  ...       0.0       0.0
# Benni Mini                             Motor V8  2019  ...       0.0       0.0
# Uno                             Motor Diesel V6  2019  ...       0.0       0.0
# Santa Fe                          Motor 3.0 32v  2019  ...       0.0       0.0
# XC60                            Motor 4.0 Turbo  2019  ...       0.0       0.0
#
# [61 rows x 9 columns]

# %%
#Substitui o NaN por 0

dataset.fillna(0, inplace=True)

# %%
dataset.query('Zero_km == True')
# Out:
#                                           Motor   Ano  ...  km_media  Km_media
# Nome                                                   ...
# DS5                             Motor 2.4 Turbo  2019  ...       0.0       0.0
# A5                              Motor 4.0 Turbo  2019  ...       0.0       0.0
# J5                                     Motor V6  2019  ...       0.0       0.0
# A3                                 Motor 1.0 8v  2019  ...       0.0       0.0
# Série 1 M                              Motor V8  2019  ...       0.0       0.0
# Lamborghini Murciélago    Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Up!                             Motor Diesel V6  2019  ...       0.0       0.0
# Sandero Stepway                   Motor 3.0 32v  2019  ...       0.0       0.0
# Pajero TR4                      Motor 2.4 Turbo  2019  ...       0.0       0.0
# Polo Sedan                             Motor V6  2019  ...       0.0       0.0
# S60                             Motor 2.4 Turbo  2019  ...       0.0       0.0
# Optima                            Motor 1.8 16v  2019  ...       0.0       0.0
# Range Rover Vogue                  Motor 1.0 8v  2019  ...       0.0       0.0
# CR-V                            Motor Diesel V8  2019  ...       0.0       0.0
# CLA                                Motor 1.0 8v  2019  ...       0.0       0.0
# Accord                                 Motor V8  2019  ...       0.0       0.0
# EXTRA 103EX                       Motor 2.0 16v  2019  ...       0.0       0.0
# Sorento                            Motor Diesel  2019  ...       0.0       0.0
# Tiggo                             Motor 3.0 32v  2019  ...       0.0       0.0
# Touareg                                Motor V8  2019  ...       0.0       0.0
# Lancer Evolution X              Motor Diesel V6  2019  ...       0.0       0.0
# Cielo Hatch                        Motor Diesel  2019  ...       0.0       0.0
# Livina                            Motor 2.0 16v  2019  ...       0.0       0.0
# Hilux                     Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Grand Siena                     Motor Diesel V8  2019  ...       0.0       0.0
# Fusion                            Motor 1.8 16v  2019  ...       0.0       0.0
# Face                                   Motor V8  2019  ...       0.0       0.0
# A8                                Motor 2.0 16v  2019  ...       0.0       0.0
# Q3                                Motor 3.0 32v  2019  ...       0.0       0.0
# Z4 Roadster                       Motor 3.0 32v  2019  ...       0.0       0.0
# Lamborghini Ferruccio             Motor 3.0 32v  2019  ...       0.0       0.0
# Camry                              Motor Diesel  2019  ...       0.0       0.0
# R8 GT                           Motor 4.0 Turbo  2019  ...       0.0       0.0
# Classe CL                              Motor V8  2019  ...       0.0       0.0
# Aston Martin Cygnet       Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Lamborghini Veneno                Motor 3.0 32v  2019  ...       0.0       0.0
# i30                               Motor 1.8 16v  2019  ...       0.0       0.0
# Voyage                    Motor 5.0 V8 Bi-Turbo  2019  ...       0.0       0.0
# Phantom I Phantom II              Motor 1.8 16v  2019  ...       0.0       0.0
# 308 CC                          Motor 4.0 Turbo  2019  ...       0.0       0.0
# L200 Triton                     Motor Diesel V8  2019  ...       0.0       0.0
# Classe SLK                      Motor 4.0 Turbo  2019  ...       0.0       0.0
# C3 Picasso                        Motor 3.0 32v  2019  ...       0.0       0.0
# Classe S                          Motor 3.0 32v  2019  ...       0.0       0.0
# T6                                Motor 3.0 32v  2019  ...       0.0       0.0
# Aston Martin Virage                Motor Diesel  2019  ...       0.0       0.0
# Vantage Volante                 Motor Diesel V8  2019  ...       0.0       0.0
# J3 Turin                               Motor V6  2019  ...       0.0       0.0
# Classe B                        Motor Diesel V8  2019  ...       0.0       0.0
# Parati                          Motor Diesel V8  2019  ...       0.0       0.0
# Sedan                                  Motor V8  2019  ...       0.0       0.0
# Aston Martin V12 Vantage               Motor V8  2019  ...       0.0       0.0
# Partner                         Motor 2.4 Turbo  2019  ...       0.0       0.0
# Chana Family                           Motor V8  2019  ...       0.0       0.0
# A3 Sedan                               Motor V6  2019  ...       0.0       0.0
# Série 7 Sedã                       Motor Diesel  2019  ...       0.0       0.0
# Lamborghini Reventón            Motor 4.0 Turbo  2019  ...       0.0       0.0
# Benni Mini                             Motor V8  2019  ...       0.0       0.0
# Uno                             Motor Diesel V6  2019  ...       0.0       0.0
# Santa Fe                          Motor 3.0 32v  2019  ...       0.0       0.0
# XC60                            Motor 4.0 Turbo  2019  ...       0.0       0.0
#
# [61 rows x 9 columns]

# %%
dataset = pd.read_csv('db.csv', sep=';')

# %%
dataset
# Out:
#                                        Nome  ...      Valor
# 0                             Jetta Variant  ...   88078.64
# 1                                    Passat  ...  106161.94
# 2                                  Crossfox  ...   72832.16
# 3                                       DS5  ...  124549.07
# 4                          Aston Martin DB4  ...   92612.10
# 5                             Palio Weekend  ...   97497.73
# 6                                        A5  ...   56445.20
# 7                            Série 3 Cabrio  ...  112310.44
# 8                              Dodge Jorney  ...  120716.27
# 9                                    Carens  ...   76566.49
# 10                                Ford Edge  ...   71647.59
# 11                                  Courier  ...   73919.53
# 12                                     S-18  ...  112732.99
# 13                                       J5  ...   53183.38
# 14                             F-Type Coupé  ...  127488.42
# 15                                      RAM  ...   59910.40
# 16                                  Série 1  ...   61118.59
# 17                                       A3  ...   88552.39
# 18                                     XC90  ...   62696.69
# 19                           RS 3 Sportback  ...  101726.30
# 20                             Pajero Sport  ...  106147.38
# 21                                Série 1 M  ...   94564.40
# 22                      Lamborghini Obvious  ...  133529.84
# 23                    Effa Hafei Picape Baú  ...  125684.65
# 24                   Lamborghini Murciélago  ...  121596.21
# 25                                      Up!  ...   71367.10
# 26                       Fiesta Rocam Sedan  ...   95347.75
# 27                          Sandero Stepway  ...  105432.84
# 28                                 Cayman S  ...   57045.27
# 29                                      V40  ...  120432.70
# 30                           Classe SLS AMG  ...   70707.20
# 31                                   Gol G4  ...   69105.18
# 32                                    Linea  ...   59358.69
# 33                                Ford F100  ...   65955.40
# 34                                       J2  ...   60017.03
# 35                         Aston Martin DBS  ...  118909.52
# 36                               Pajero TR4  ...   51606.59
# 37                               Polo Sedan  ...  123281.87
# 38                               California  ...   69770.18
# 39                                      S60  ...  102609.54
# 40                                   Tucson  ...   67997.19
# 41                                     HB20  ...  135235.29
# 42                                   Optima  ...   86641.34
# 43                                    Logan  ...  136818.39
# 44                        Range Rover Vogue  ...  117626.73
# 45                                   Sonata  ...   56208.70
# 46                    Ford New Fiesta Sedan  ...   84222.65
# 47                     Série 5 Gran Turismo  ...   90781.65
# 48                                     CR-V  ...   64701.10
# 49                            Ford EcoSport  ...  126350.49
# 50                                    Versa  ...  148152.89
# 51                                 Classe E  ...  132298.83
# 52                                 Carnival  ...  137627.63
# 53         Aston Martin V8 Vantage Roadster  ...   80422.71
# 54                                   Hoggar  ...   56373.99
# 55                                       A1  ...   70846.03
# 56                 Aston Martin DB7 Vantage  ...  128694.23
# 57                                      CLA  ...  133329.19
# 58                                   Accord  ...  131961.43
# 59                              EXTRA 103EX  ...  112033.27
# 60                                  Sorento  ...   81399.35
# 61                                    Tiggo  ...   97163.10
# 62                         New Fiesta Hatch  ...   66007.16
# 63                            Jeep Renegade  ...  128776.22
# 64                     Lamborghini Ankonian  ...  142623.02
# 65                              Space Cross  ...  136930.13
# 66                                  Touareg  ...   66526.61
# 67                                 Classe M  ...  114154.87
# 68                       Lancer Evolution X  ...  142392.75
# 69                           Kangoo Express  ...  146716.91
# 70                                      SW4  ...  122485.68
# 71                             Cadillac ELR  ...   97951.03
# 72                                    Doblò  ...   78283.49
# 73                      Lamborghini Egoista  ...   83434.04
# 74                                      Fit  ...   77836.23
# 75                                       C5  ...   60813.92
# 76                              Celer Hatch  ...   91353.86
# 77                                    HB20S  ...  116281.21
# 78                              Cielo Hatch  ...  145197.70
# 79                                   Livina  ...   50742.10
# 80                                   Ducato  ...   73033.53
# 81                                    March  ...   54332.87
# 82                       Cadillac XTS sedan  ...   52207.45
# 83                   Lamborghini Centenario  ...   63578.50
# 84                                    Hilux  ...   64507.72
# 85                              Grand Siena  ...  115075.59
# 86                                   Symbol  ...  133030.60
# 87               Aston Martin V12 GT Zagato  ...  141591.86
# 88                                   Fusion  ...  100380.28
# 89                                 A4 Sedan  ...   96369.04
# 90                            Xsara Picasso  ...  142603.84
# 91                                   207 SW  ...  117709.67
# 92                                     Star  ...  102241.54
# 93                              Doblò Cargo  ...   96065.38
# 94                             Cadillac CTS  ...   53894.61
# 95                                  Cayenne  ...  123911.78
# 96                                      Fox  ...  101996.35
# 97                              Tiida Hatch  ...   83431.66
# 98                            Dodge Charger  ...  122975.63
# 99                                     Face  ...   93227.73
# 100                                   Prius  ...   58762.65
# 101                                    Idea  ...  139549.67
# 102                                      A8  ...  122016.42
# 103                          Série 1 Cabrio  ...   72731.98
# 104                                    Edge  ...   88416.54
# 105                      Cadillac ATS sedan  ...   73873.42
# 106          Lamborghini Asterion LPI 910-4  ...   70709.34
# 107                                Frontier  ...  115306.50
# 108                            Série 3 Sedã  ...   55924.63
# 109                       Lamborghini LM002  ...   85052.26
# 110                            Cadillac XLR  ...   56646.34
# 111                                A4 Avant  ...  138946.88
# 112                                EcoSport  ...  108256.72
# 113                                      J3  ...   58979.30
# 114                                      Q3  ...  114727.68
# 115                 Aston Martin V8 Vantage  ...  139661.48
# 116                             Z4 Roadster  ...   80382.24
# 117                   Lamborghini Ferruccio  ...  149157.17
# 118                                Ford Ka+  ...   87830.41
# 119                           Silver Shadow  ...  143568.22
# 120                 Classe C 63 AMG Touring  ...  138171.85
# 121                             Discovery 4  ...  115784.95
# 122                                Veloster  ...  146508.99
# 123                                Classe C  ...  137670.23
# 124                                   Camry  ...  138597.27
# 125                               C5 Tourer  ...  147627.81
# 126                                   R8 GT  ...   62999.02
# 127                                   Bongo  ...   91242.44
# 128                                     ASX  ...  149489.92
# 129                            Cadillac SRX  ...   63529.95
# 130                               Classe CL  ...   58525.41
# 131                              500 Abarth  ...   90345.05
# 132                     Aston Martin Cygnet  ...  147770.87
# 133                            Cadillac STS  ...  106617.71
# 134                        Aston Martin DB9  ...  104929.88
# 135                                 NX 200t  ...  100712.45
# 136                     Aston Martin One-77  ...  141982.93
# 137                      Lamborghini Veneno  ...  104038.79
# 138                                  Sentra  ...   88501.54
# 139                                  Jumper  ...   79782.02
# 140                                     i30  ...   86224.10
# 141                                      X6  ...  103596.18
# 142                                  Voyage  ...  148996.47
# 143                    Phantom I Phantom II  ...   60948.01
# 144                          Passat Variant  ...   69535.44
# 145                                    Clio  ...  111130.33
# 146                                Classe G  ...   65847.69
# 147                            Silver Ghost  ...   78096.06
# 148                        Série 3 M3 Coupé  ...   69219.89
# 149                     Gallardo LP 560 – 4  ...  144118.91
# 150                            Freelander 2  ...   77397.05
# 151                          Grand Cherokee  ...   68974.25
# 152                       Aston Martin DBR9  ...  125231.30
# 153                                    Soul  ...   85501.12
# 154                            Cadillac BLS  ...  137116.21
# 155                                  RX 350  ...  138823.81
# 156                                  Cayman  ...  117961.95
# 157                           Chana Utility  ...  132662.32
# 158                                  308 CC  ...  146405.79
# 159                             L200 Triton  ...   81999.21
# 160                                   Jetta  ...  140934.60
# 161                               C4 Lounge  ...   82366.81
# 162                               C4 Pallas  ...   70424.11
# 163                                   Equus  ...   53620.31
# 164                               Classe GL  ...   73389.18
# 165                      Range Rover Evoque  ...  111618.12
# 166                                Cherokee  ...  112187.37
# 167                                   Punto  ...  120812.57
# 168                              Grand Tour  ...  116031.04
# 169                                 Fluence  ...  125398.11
# 170        Effa Hafei Picape Cabine Simples  ...   76101.47
# 171                                 Durango  ...   75263.24
# 172                                 Boxster  ...  147387.76
# 173                             TT Roadster  ...   85311.40
# 174                       Lamborghini Jalpa  ...   54388.11
# 175                              Classe SLK  ...  124156.65
# 176                                    Golf  ...  146203.34
# 177                              C3 Picasso  ...   56453.94
# 178                                     V50  ...   68873.79
# 179                                 Picanto  ...   91667.61
# 180                                 Cadenza  ...   93776.52
# 181                              Etios Sedã  ...   66433.82
# 182                                  Alsvin  ...  109059.27
# 183                            Cadillac ATS  ...  122069.97
# 184                         Série 3 M3 Sedã  ...  113090.32
# 185                                Classe S  ...   89401.10
# 186                                      T6  ...   56842.79
# 187                        Aston Martin DB7  ...  146676.71
# 188                               207 Sedan  ...   89511.96
# 189                     Aston Martin Virage  ...   97290.18
# 190                                   Azera  ...  120673.56
# 191                         Vantage Volante  ...  114434.94
# 192                                Siena EL  ...  139546.69
# 193                         Palio Adventure  ...   95078.16
# 194                                   HB20X  ...   68091.77
# 195                                      HR  ...   61496.97
# 196                   Cadillac STS V-Series  ...  139669.30
# 197                           Série 1 Coupé  ...   80661.39
# 198                                SpaceFox  ...   61783.65
# 199                                     C30  ...   52805.91
# 200                                J3 Turin  ...  127024.75
# 201                                Classe B  ...  135543.00
# 202                                  Parati  ...  121708.73
# 203                   Cadillac CTS V-Series  ...  107342.68
# 204                                   Sedan  ...   57888.10
# 205                       Classe CLS 63 AMG  ...  118161.48
# 206                                Aircross  ...  142499.06
# 207                Aston Martin V12 Vantage  ...  128396.11
# 208                                 Sandero  ...  112350.61
# 209                              New Fiesta  ...  124661.38
# 210                                     XKR  ...   54263.16
# 211                                      X5  ...   62041.32
# 212                            Cadillac DTS  ...  129296.11
# 213                            Pajero Dakar  ...   60998.33
# 214                                Classe A  ...   58008.50
# 215                     Ford Focus Fastback  ...   82304.19
# 216                                 Partner  ...  114531.74
# 217                                      R8  ...  128565.61
# 218                Aston Martin DBS Volante  ...  126488.26
# 219                                  Mohave  ...  119074.55
# 220                                   Fusca  ...  130238.04
# 221                            Chana Family  ...  115760.17
# 222                                    XC40  ...  121248.00
# 223  Phantom I Jonckheere Aerodynamic Coupe  ...   98156.35
# 224                                   Boxer  ...  112146.80
# 225                             Chana Cargo  ...  102729.63
# 226                            Dodge Dakota  ...  141083.35
# 227                                      X1  ...  102968.76
# 228                                     GLA  ...   76310.01
# 229                       Range Rover Sport  ...  120481.74
# 230                                     DS3  ...   54559.18
# 231                                Veracruz  ...   92957.64
# 232    Cadillac CTS coupe, sedan, and wagon  ...  127810.06
# 233                                  i30 CW  ...   73311.75
# 234                             Phantom III  ...   65138.03
# 235                                A3 Sedan  ...   90141.47
# 236                Aston Martin DB9 Volante  ...   71160.36
# 237                            Série 7 Sedã  ...   67539.79
# 238                    Lamborghini Reventón  ...   67664.86
# 239                            Grand Livina  ...   68652.16
# 240                                     V60  ...  114728.74
# 241          Effa Hafei Picape Cabine Dupla  ...  141645.08
# 242                              Benni Mini  ...  126247.84
# 243                                     Uno  ...  128852.21
# 244                             L200 Savana  ...  132384.76
# 245                                Santa Fe  ...  129415.33
# 246                                     RS5  ...   89536.82
# 247                                  Cerato  ...   87975.30
# 248                                    XC60  ...   77675.79
# 249                                 LS 460L  ...   58881.67
# 250              Lamborghini Sesto Elemento  ...   55081.99
# 251                     Lamborghini Huracán  ...  118826.44
# 252                                      A7  ...  137627.62
# 253                            Phantom 2013  ...   51759.58
# 254                   Cadillac Ciel concept  ...   51667.06
# 255                              Classe GLK  ...   68934.03
# 256                        Aston Martin DB5  ...  122110.90
# 257                                   Macan  ...   90381.47
#
# [258 rows x 7 columns]

# %%
dataset.dropna(subset=['Quilometragem'], inplace=True)

# %%
dataset
# Out:
#                                        Nome  ...      Valor
# 0                             Jetta Variant  ...   88078.64
# 1                                    Passat  ...  106161.94
# 2                                  Crossfox  ...   72832.16
# 4                          Aston Martin DB4  ...   92612.10
# 5                             Palio Weekend  ...   97497.73
# 7                            Série 3 Cabrio  ...  112310.44
# 8                              Dodge Jorney  ...  120716.27
# 9                                    Carens  ...   76566.49
# 10                                Ford Edge  ...   71647.59
# 11                                  Courier  ...   73919.53
# 12                                     S-18  ...  112732.99
# 14                             F-Type Coupé  ...  127488.42
# 15                                      RAM  ...   59910.40
# 16                                  Série 1  ...   61118.59
# 18                                     XC90  ...   62696.69
# 19                           RS 3 Sportback  ...  101726.30
# 20                             Pajero Sport  ...  106147.38
# 22                      Lamborghini Obvious  ...  133529.84
# 23                    Effa Hafei Picape Baú  ...  125684.65
# 26                       Fiesta Rocam Sedan  ...   95347.75
# 28                                 Cayman S  ...   57045.27
# 29                                      V40  ...  120432.70
# 30                           Classe SLS AMG  ...   70707.20
# 31                                   Gol G4  ...   69105.18
# 32                                    Linea  ...   59358.69
# 33                                Ford F100  ...   65955.40
# 34                                       J2  ...   60017.03
# 35                         Aston Martin DBS  ...  118909.52
# 38                               California  ...   69770.18
# 40                                   Tucson  ...   67997.19
# 41                                     HB20  ...  135235.29
# 43                                    Logan  ...  136818.39
# 45                                   Sonata  ...   56208.70
# 46                    Ford New Fiesta Sedan  ...   84222.65
# 47                     Série 5 Gran Turismo  ...   90781.65
# 49                            Ford EcoSport  ...  126350.49
# 50                                    Versa  ...  148152.89
# 51                                 Classe E  ...  132298.83
# 52                                 Carnival  ...  137627.63
# 53         Aston Martin V8 Vantage Roadster  ...   80422.71
# 54                                   Hoggar  ...   56373.99
# 55                                       A1  ...   70846.03
# 56                 Aston Martin DB7 Vantage  ...  128694.23
# 62                         New Fiesta Hatch  ...   66007.16
# 63                            Jeep Renegade  ...  128776.22
# 64                     Lamborghini Ankonian  ...  142623.02
# 65                              Space Cross  ...  136930.13
# 67                                 Classe M  ...  114154.87
# 69                           Kangoo Express  ...  146716.91
# 70                                      SW4  ...  122485.68
# 71                             Cadillac ELR  ...   97951.03
# 72                                    Doblò  ...   78283.49
# 73                      Lamborghini Egoista  ...   83434.04
# 74                                      Fit  ...   77836.23
# 75                                       C5  ...   60813.92
# 76                              Celer Hatch  ...   91353.86
# 77                                    HB20S  ...  116281.21
# 80                                   Ducato  ...   73033.53
# 81                                    March  ...   54332.87
# 82                       Cadillac XTS sedan  ...   52207.45
# 83                   Lamborghini Centenario  ...   63578.50
# 86                                   Symbol  ...  133030.60
# 87               Aston Martin V12 GT Zagato  ...  141591.86
# 89                                 A4 Sedan  ...   96369.04
# 90                            Xsara Picasso  ...  142603.84
# 91                                   207 SW  ...  117709.67
# 92                                     Star  ...  102241.54
# 93                              Doblò Cargo  ...   96065.38
# 94                             Cadillac CTS  ...   53894.61
# 95                                  Cayenne  ...  123911.78
# 96                                      Fox  ...  101996.35
# 97                              Tiida Hatch  ...   83431.66
# 98                            Dodge Charger  ...  122975.63
# 100                                   Prius  ...   58762.65
# 101                                    Idea  ...  139549.67
# 103                          Série 1 Cabrio  ...   72731.98
# 104                                    Edge  ...   88416.54
# 105                      Cadillac ATS sedan  ...   73873.42
# 106          Lamborghini Asterion LPI 910-4  ...   70709.34
# 107                                Frontier  ...  115306.50
# 108                            Série 3 Sedã  ...   55924.63
# 109                       Lamborghini LM002  ...   85052.26
# 110                            Cadillac XLR  ...   56646.34
# 111                                A4 Avant  ...  138946.88
# 112                                EcoSport  ...  108256.72
# 113                                      J3  ...   58979.30
# 115                 Aston Martin V8 Vantage  ...  139661.48
# 118                                Ford Ka+  ...   87830.41
# 119                           Silver Shadow  ...  143568.22
# 120                 Classe C 63 AMG Touring  ...  138171.85
# 121                             Discovery 4  ...  115784.95
# 122                                Veloster  ...  146508.99
# 123                                Classe C  ...  137670.23
# 125                               C5 Tourer  ...  147627.81
# 127                                   Bongo  ...   91242.44
# 128                                     ASX  ...  149489.92
# 129                            Cadillac SRX  ...   63529.95
# 131                              500 Abarth  ...   90345.05
# 133                            Cadillac STS  ...  106617.71
# 134                        Aston Martin DB9  ...  104929.88
# 135                                 NX 200t  ...  100712.45
# 136                     Aston Martin One-77  ...  141982.93
# 138                                  Sentra  ...   88501.54
# 139                                  Jumper  ...   79782.02
# 141                                      X6  ...  103596.18
# 144                          Passat Variant  ...   69535.44
# 145                                    Clio  ...  111130.33
# 146                                Classe G  ...   65847.69
# 147                            Silver Ghost  ...   78096.06
# 148                        Série 3 M3 Coupé  ...   69219.89
# 149                     Gallardo LP 560 – 4  ...  144118.91
# 150                            Freelander 2  ...   77397.05
# 151                          Grand Cherokee  ...   68974.25
# 152                       Aston Martin DBR9  ...  125231.30
# 153                                    Soul  ...   85501.12
# 154                            Cadillac BLS  ...  137116.21
# 155                                  RX 350  ...  138823.81
# 156                                  Cayman  ...  117961.95
# 157                           Chana Utility  ...  132662.32
# 160                                   Jetta  ...  140934.60
# 161                               C4 Lounge  ...   82366.81
# 162                               C4 Pallas  ...   70424.11
# 163                                   Equus  ...   53620.31
# 164                               Classe GL  ...   73389.18
# 165                      Range Rover Evoque  ...  111618.12
# 166                                Cherokee  ...  112187.37
# 167                                   Punto  ...  120812.57
# 168                              Grand Tour  ...  116031.04
# 169                                 Fluence  ...  125398.11
# 170        Effa Hafei Picape Cabine Simples  ...   76101.47
# 171                                 Durango  ...   75263.24
# 172                                 Boxster  ...  147387.76
# 173                             TT Roadster  ...   85311.40
# 174                       Lamborghini Jalpa  ...   54388.11
# 176                                    Golf  ...  146203.34
# 178                                     V50  ...   68873.79
# 179                                 Picanto  ...   91667.61
# 180                                 Cadenza  ...   93776.52
# 181                              Etios Sedã  ...   66433.82
# 182                                  Alsvin  ...  109059.27
# 183                            Cadillac ATS  ...  122069.97
# 184                         Série 3 M3 Sedã  ...  113090.32
# 187                        Aston Martin DB7  ...  146676.71
# 188                               207 Sedan  ...   89511.96
# 190                                   Azera  ...  120673.56
# 192                                Siena EL  ...  139546.69
# 193                         Palio Adventure  ...   95078.16
# 194                                   HB20X  ...   68091.77
# 195                                      HR  ...   61496.97
# 196                   Cadillac STS V-Series  ...  139669.30
# 197                           Série 1 Coupé  ...   80661.39
# 198                                SpaceFox  ...   61783.65
# 199                                     C30  ...   52805.91
# 203                   Cadillac CTS V-Series  ...  107342.68
# 205                       Classe CLS 63 AMG  ...  118161.48
# 206                                Aircross  ...  142499.06
# 208                                 Sandero  ...  112350.61
# 209                              New Fiesta  ...  124661.38
# 210                                     XKR  ...   54263.16
# 211                                      X5  ...   62041.32
# 212                            Cadillac DTS  ...  129296.11
# 213                            Pajero Dakar  ...   60998.33
# 214                                Classe A  ...   58008.50
# 215                     Ford Focus Fastback  ...   82304.19
# 217                                      R8  ...  128565.61
# 218                Aston Martin DBS Volante  ...  126488.26
# 219                                  Mohave  ...  119074.55
# 220                                   Fusca  ...  130238.04
# 222                                    XC40  ...  121248.00
# 223  Phantom I Jonckheere Aerodynamic Coupe  ...   98156.35
# 224                                   Boxer  ...  112146.80
# 225                             Chana Cargo  ...  102729.63
# 226                            Dodge Dakota  ...  141083.35
# 227                                      X1  ...  102968.76
# 228                                     GLA  ...   76310.01
# 229                       Range Rover Sport  ...  120481.74
# 230                                     DS3  ...   54559.18
# 231                                Veracruz  ...   92957.64
# 232    Cadillac CTS coupe, sedan, and wagon  ...  127810.06
# 233                                  i30 CW  ...   73311.75
# 234                             Phantom III  ...   65138.03
# 236                Aston Martin DB9 Volante  ...   71160.36
# 239                            Grand Livina  ...   68652.16
# 240                                     V60  ...  114728.74
# 241          Effa Hafei Picape Cabine Dupla  ...  141645.08
# 244                             L200 Savana  ...  132384.76
# 246                                     RS5  ...   89536.82
# 247                                  Cerato  ...   87975.30
# 249                                 LS 460L  ...   58881.67
# 250              Lamborghini Sesto Elemento  ...   55081.99
# 251                     Lamborghini Huracán  ...  118826.44
# 252                                      A7  ...  137627.62
# 253                            Phantom 2013  ...   51759.58
# 254                   Cadillac Ciel concept  ...   51667.06
# 255                              Classe GLK  ...   68934.03
# 256                        Aston Martin DB5  ...  122110.90
# 257                                   Macan  ...   90381.47
#
# [197 rows x 7 columns]
